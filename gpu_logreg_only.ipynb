# %%
import re
import traceback
import time
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col, length, concat_ws, regexp_replace, size, split 
from pyspark.sql.types import StringType, IntegerType, DoubleType, ArrayType
from pyspark.ml import Pipeline
from pyspark.ml.feature import (
    Tokenizer, StopWordsRemover, HashingTF, IDF, StringIndexer,
    VectorAssembler, NGram, Word2Vec
)
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

spark = (SparkSession.builder
    .appName("GPU_IMP_RECOMMENDED")
    .master("local[*]")
    .config("spark.driver.memory","24g")
    .config("spark.executor.memory", "24g")
    .config("spark.executor.cores", "4")
    .config("spark.driver.cores", "4")
    .config("spark.sql.shuffle.partitions", "200")
    .config("spark.plugins", "com.nvidia.spark.SQLPlugin")
    .config("spark.driver.host", "localhost")
    .config("spark.rapids.sql.explain", "ALL") 
    .config("spark.rapids.sql.allowMultipleJars", "ALWAYS")
    .config("spark.rapids.sql.enabled", "true")
    .config("spark.rapids.memory.hostStorageFraction", "0.8")
    .config("spark.rapids.memory.deviceStorageFraction", "0.8")
    .config("spark.rapids.sql.concurrentGpuTasks", "2")
    .config("spark.memory.offHeap.enabled", "true")
    .config("spark.memory.offHeap.size", "8g") 
    .config("spark.rapids.memory.gpu.allocation.limit", "0.9")
    .config("spark.rapids.host.shim.async", "true")
    .config("spark.sql.session.timeZone", "UTC")
    .config("spark.rapids.sql.exec.CollectLimitExec", "true")
    .config("spark.rapids.sql.rowBasedUDF.enabled", "true")
    .config("spark.sql.inMemoryColumnarStorage.batchSerializer", "com.nvidia.spark.rapids.shims.SparkShimServiceProvider")
    .getOrCreate()
)

data_path = "/mnt/c/Users/BerenÜnveren/Desktop/BIL401/data/train.csv"

def clean_tags(tags):
    if tags is None: return []
    return [tag.strip() for tag in tags.replace('<', ' ').replace('>', ' ').split() if tag.strip()]
clean_tags_udf = udf(clean_tags, ArrayType(StringType()))

try:
    print("--- Data Loading ---")
    start_load_time = time.time()
    df = spark.read.format("csv") \
        .option("header", "true") \
        .option("quote", "\"") \
        .option("escape", "\"") \
        .option("multiLine", "true") \
        .option("inferSchema", "true") \
        .load(data_path)
    load_time = time.time() - start_load_time
    print(f"Data load time: {load_time:.2f} seconds")
    print("data schema:")
    df.printSchema()
    print("Y column distribution after load (should be HQ, LQ_EDIT, LQ_CLOSE):")
    df.groupBy("Y").count().show()

    print("--- Data Cleaning and Feature Engineering (initial steps) ---")
    start_clean_feature_time = time.time()
    df_clean = df.na.drop(subset=["Title", "Body", "Tags", "Y"]) \
        .withColumn("CleanBody", regexp_replace(col("Body"), "<.*?>", "")) \
        .withColumn("text", concat_ws(" ", col("Title"), col("CleanBody"))) \
        .withColumn("tags_list", clean_tags_udf(col("Tags")))

    df_featured = df_clean.withColumn("title_len", length(col("Title"))) \
        .withColumn("body_len", length(col("CleanBody"))) \
        .withColumn("punct_count", length(regexp_replace(col("text"), "[?!]", ""))) \
        .withColumn("avg_word_len", length(regexp_replace(col("text"), " ", "")) / (size(split(col("text"), " ")) + 1e-6))
    clean_feature_time = time.time() - start_clean_feature_time
    print(f"Initial data cleaning and feature engineering time: {clean_feature_time:.2f} seconds")

    label_indexer = StringIndexer(inputCol="Y", outputCol="label", handleInvalid="skip")
    tokenizer = Tokenizer(inputCol="text", outputCol="words")
    stopwords_remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")
    ngram = NGram(n=2, inputCol="filtered_words", outputCol="bigrams")

    hashing_tf_text = HashingTF(inputCol="filtered_words", outputCol="raw_text_features", numFeatures=20000)
    idf_text = IDF(inputCol="raw_text_features", outputCol="text_features")

    hashing_tf_bigrams = HashingTF(inputCol="bigrams", outputCol="raw_bigrams_features", numFeatures=20000)
    idf_bigrams = IDF(inputCol="raw_bigrams_features", outputCol="bigrams_features")

    w2v = Word2Vec(vectorSize=100, minCount=5, inputCol="filtered_words", outputCol="w2v_features")

    hashing_tf_tags = HashingTF(inputCol="tags_list", outputCol="raw_tags_features", numFeatures=5000)
    idf_tags = IDF(inputCol="raw_tags_features", outputCol="tags_tags")

    feature_assembler = VectorAssembler(
        inputCols=["text_features", "bigrams_features", "w2v_features", "tags_tags",
                   "title_len", "body_len", "punct_count", "avg_word_len"],
        outputCol="features"
    )

    (train_data, test_data) = df_featured.randomSplit([0.8, 0.2], seed=42)
    train_data.cache()
    test_data.cache()
    train_data.count()
    test_data.count() 

    print(f"Train data count: {train_data.count()}, Test data count: {test_data.count()}")

    print("\n--- Logistic Regression Training ---")
    lr = LogisticRegression(featuresCol="features", labelCol="label", maxIter=10)
    lr_pipeline = Pipeline(stages=[
        label_indexer, tokenizer, stopwords_remover, ngram,
        hashing_tf_text, idf_text, hashing_tf_bigrams, idf_bigrams, w2v, hashing_tf_tags, idf_tags,
        feature_assembler, lr
    ])

    start_lr_train_time = time.time()
    
    lr_model = lr_pipeline.fit(train_data) 
    lr_train_time = time.time() - start_lr_train_time
    print(f"Logistic Regression training time: {lr_train_time:.2f} seconds")

    start_lr_predict_time = time.time()
    lr_predictions = lr_model.transform(test_data)
    lr_predict_time = time.time() - start_lr_predict_time
    print(f"Logistic Regression prediction time: {lr_predict_time:.2f} seconds")

    evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction")
    accuracy_lr = evaluator.setMetricName("accuracy").evaluate(lr_predictions)
    f1_score_lr = evaluator.setMetricName("f1").evaluate(lr_predictions)

    print("\nLogistic Regression Results:")
    print(f"Accuracy: {accuracy_lr:.4f}")
    print(f"F1 Score: {f1_score_lr:.4f}")
    print("Confusion Matrix:")
    lr_predictions.groupBy("label", "prediction").count().orderBy("label", "prediction").show()

except Exception as e:
    print(f"An error occurred: {e}")
    traceback.print_exc()
finally:
    try:
        spark.stop()
    except Exception as e:
        print(f"Error stopping Spark session: {e}")
        traceback.print_exc()
# Out:
# 25/07/22 23:33:31 WARN Utils: Your hostname, DESKTOP-15VE119 resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/07/22 23:33:32 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/07/22 23:33:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/07/22 23:33:34 WARN RapidsPluginUtils: RAPIDS Accelerator 24.02.0 using cudf 24.02.1.
# 25/07/22 23:33:34 WARN RapidsPluginUtils: spark.rapids.sql.multiThreadedRead.numThreads is set to 20.
# 25/07/22 23:33:34 WARN RapidsPluginUtils: Multiple cudf jars found in the classpath:
# revison: dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/rapids-4-spark_2.12-24.02.0.jar
# 	version=24.02.1
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T05:34:16Z
# 	url=https://github.com/rapidsai/cudf.git
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/cudf-24.02.2-cuda12.jar
# 	version=24.02.2
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T07:51:45Z
# Please make sure there is only one cudf jar in the classpath.
# 25/07/22 23:33:34 WARN RapidsPluginUtils: RAPIDS Accelerator is enabled, to disable GPU support set `spark.rapids.sql.enabled` to false.
# 25/07/22 23:33:34 WARN RapidsPluginUtils: spark.rapids.sql.explain is set to `ALL`. Set it to 'NONE' to suppress the diagnostics logging about the query placement on the GPU.
# 25/07/22 23:33:41 WARN RapidsPluginUtils: Multiple cudf jars found in the classpath:
# revison: dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/rapids-4-spark_2.12-24.02.0.jar
# 	version=24.02.1
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T05:34:16Z
# 	url=https://github.com/rapidsai/cudf.git
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/cudf-24.02.2-cuda12.jar
# 	version=24.02.2
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T07:51:45Z
# Please make sure there is only one cudf jar in the classpath.
# --- Data Loading ---
# 25/07/22 23:33:50 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# Data load time: 3.85 seconds
# data schema:
# root
#  |-- Id: integer (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Body: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- CreationDate: timestamp (nullable = true)
#  |-- Y: string (nullable = true)
#
# Y column distribution after load (should be HQ, LQ_EDIT, LQ_CLOSE):
# 25/07/22 23:33:54 WARN GpuOverrides:
# *Exec <CollectLimitExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     *Expression <Alias> toprettystring(Y#5, Some(UTC)) AS toprettystring(Y)#25 will run on GPU
#       *Expression <ToPrettyString> toprettystring(Y#5, Some(UTC)) will run on GPU
#     *Expression <Alias> toprettystring(count(1)#18L, Some(UTC)) AS toprettystring(count)#26 will run on GPU
#       *Expression <ToPrettyString> toprettystring(count(1)#18L, Some(UTC)) will run on GPU
#     *Exec <ShuffleExchangeExec> will run on GPU
#       *Partitioning <HashPartitioning> will run on GPU
#       *Exec <HashAggregateExec> will run on GPU
#         *Expression <AggregateExpression> partial_count(1) will run on GPU
#           *Expression <Count> count(1) will run on GPU
#         !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 23:33:54 WARN GpuOverrides:
# *Exec <CollectLimitExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     *Expression <Alias> toprettystring(Y#5, Some(UTC)) AS toprettystring(Y)#25 will run on GPU
#       *Expression <ToPrettyString> toprettystring(Y#5, Some(UTC)) will run on GPU
#     *Expression <Alias> toprettystring(count(1)#18L, Some(UTC)) AS toprettystring(count)#26 will run on GPU
#       *Expression <ToPrettyString> toprettystring(count(1)#18L, Some(UTC)) will run on GPU
#     *Exec <ShuffleExchangeExec> will run on GPU
#       *Partitioning <HashPartitioning> will run on GPU
#       *Exec <HashAggregateExec> will run on GPU
#         *Expression <AggregateExpression> partial_count(1) will run on GPU
#           *Expression <Count> count(1) will run on GPU
#         !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 23:33:54 WARN GpuOverrides:
# *Exec <CollectLimitExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     *Expression <Alias> toprettystring(Y#5, Some(UTC)) AS toprettystring(Y)#25 will run on GPU
#       *Expression <ToPrettyString> toprettystring(Y#5, Some(UTC)) will run on GPU
#     *Expression <Alias> toprettystring(count(1)#18L, Some(UTC)) AS toprettystring(count)#26 will run on GPU
#       *Expression <ToPrettyString> toprettystring(count(1)#18L, Some(UTC)) will run on GPU
#     *Exec <ShuffleExchangeExec> will run on GPU
#       *Partitioning <HashPartitioning> will run on GPU
#       *Exec <HashAggregateExec> will run on GPU
#         *Expression <AggregateExpression> partial_count(1) will run on GPU
#           *Expression <Count> count(1) will run on GPU
#         !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 23:33:54 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <HashPartitioning> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 23:33:56 WARN GpuOverrides:                                (0 + 1) / 1]
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> toprettystring(Y#5, Some(UTC)) AS toprettystring(Y)#25 will run on GPU
#     *Expression <ToPrettyString> toprettystring(Y#5, Some(UTC)) will run on GPU
#   *Expression <Alias> toprettystring(count(1)#18L, Some(UTC)) AS toprettystring(count)#26 will run on GPU
#     *Expression <ToPrettyString> toprettystring(count(1)#18L, Some(UTC)) will run on GPU
#
# 25/07/22 23:33:56 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> toprettystring(Y#5, Some(UTC)) AS toprettystring(Y)#25 will run on GPU
#     *Expression <ToPrettyString> toprettystring(Y#5, Some(UTC)) will run on GPU
#   *Expression <Alias> toprettystring(count(1)#18L, Some(UTC)) AS toprettystring(count)#26 will run on GPU
#     *Expression <ToPrettyString> toprettystring(count(1)#18L, Some(UTC)) will run on GPU
#   *Exec <AQEShuffleReadExec> will run on GPU
# +--------+-----+
# |       Y|count|
# +--------+-----+
# |LQ_CLOSE|15000|
# |      HQ|15000|
# | LQ_EDIT|15000|
# +--------+-----+
#
# --- Data Cleaning and Feature Engineering (initial steps) ---
# Initial data cleaning and feature engineering time: 0.19 seconds
# 25/07/22 23:33:58 WARN GpuOverrides:
# *Exec <SampleExec> will run on GPU
#   *Exec <SortExec> will run on GPU
#     *Expression <SortOrder> Id#0 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Title#1 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Body#2 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Tags#3 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> CreationDate#4 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Y#5 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> CleanBody#59 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> text#67 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> tags_list#77 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> title_len#87 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> body_len#98 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> punct_count#110 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> avg_word_len#123 ASC NULLS FIRST will run on GPU
#     *Exec <ProjectExec> will run on GPU
#       *Expression <Alias> length(regexp_replace(text#67, [?!], , 1)) AS punct_count#110 will run on GPU
#         *Expression <Length> length(regexp_replace(text#67, [?!], , 1)) will run on GPU
#           *Expression <RegExpReplace> regexp_replace(text#67, [?!], , 1) will run on GPU
#       *Expression <Alias> (cast(length(regexp_replace(text#67,  , , 1)) as double) / (cast(size(split(text#67,  , -1), true) as double) + 1.0E-6)) AS avg_word_len#123 will run on GPU
#         *Expression <Divide> (cast(length(regexp_replace(text#67,  , , 1)) as double) / (cast(size(split(text#67,  , -1), true) as double) + 1.0E-6)) will run on GPU
#           *Expression <Cast> cast(length(regexp_replace(text#67,  , , 1)) as double) will run on GPU
#             *Expression <Length> length(regexp_replace(text#67,  , , 1)) will run on GPU
#               *Expression <RegExpReplace> regexp_replace(text#67,  , , 1) will run on GPU
#           *Expression <Add> (cast(size(split(text#67,  , -1), true) as double) + 1.0E-6) will run on GPU
#             *Expression <Cast> cast(size(split(text#67,  , -1), true) as double) will run on GPU
#               *Expression <Size> size(split(text#67,  , -1), true) will run on GPU
#                 *Expression <StringSplit> split(text#67,  , -1) will run on GPU
#       *Exec <ProjectExec> will run on GPU
#         *Expression <Alias> concat_ws( , Title#1, CleanBody#59) AS text#67 will run on GPU
#           *Expression <ConcatWs> concat_ws( , Title#1, CleanBody#59) will run on GPU
#         *Expression <Alias> pythonUDF0#137 AS tags_list#77 will run on GPU
#         *Expression <Alias> length(Title#1) AS title_len#87 will run on GPU
#           *Expression <Length> length(Title#1) will run on GPU
#         *Expression <Alias> length(CleanBody#59) AS body_len#98 will run on GPU
#           *Expression <Length> length(CleanBody#59) will run on GPU
#         ! <BatchEvalPythonExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.python.BatchEvalPythonExec
#           @Expression <PythonUDF> clean_tags(Tags#3)#76 could not block GPU acceleration
#             @Expression <AttributeReference> Tags#3 could run on GPU
#           @Expression <AttributeReference> pythonUDF0#137 could run on GPU
#           *Exec <ProjectExec> will run on GPU
#             *Expression <Alias> regexp_replace(Body#2, <.*?>, , 1) AS CleanBody#59 will run on GPU
#               *Expression <RegExpReplace> regexp_replace(Body#2, <.*?>, , 1) will run on GPU
#             *Exec <FilterExec> will run on GPU
#               *Expression <AtLeastNNonNulls> atleastnnonnulls(4, Title#1, Body#2, Tags#3, Y#5) will run on GPU
#               !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 23:33:58 WARN GpuOverrides:
# *Exec <SampleExec> will run on GPU
#   *Exec <SortExec> will run on GPU
#     *Expression <SortOrder> Id#0 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Title#1 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Body#2 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Tags#3 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> CreationDate#4 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Y#5 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> CleanBody#59 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> text#67 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> tags_list#77 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> title_len#87 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> body_len#98 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> punct_count#110 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> avg_word_len#123 ASC NULLS FIRST will run on GPU
#     *Exec <ProjectExec> will run on GPU
#       *Expression <Alias> length(regexp_replace(text#67, [?!], , 1)) AS punct_count#110 will run on GPU
#         *Expression <Length> length(regexp_replace(text#67, [?!], , 1)) will run on GPU
#           *Expression <RegExpReplace> regexp_replace(text#67, [?!], , 1) will run on GPU
#       *Expression <Alias> (cast(length(regexp_replace(text#67,  , , 1)) as double) / (cast(size(split(text#67,  , -1), true) as double) + 1.0E-6)) AS avg_word_len#123 will run on GPU
#         *Expression <Divide> (cast(length(regexp_replace(text#67,  , , 1)) as double) / (cast(size(split(text#67,  , -1), true) as double) + 1.0E-6)) will run on GPU
#           *Expression <Cast> cast(length(regexp_replace(text#67,  , , 1)) as double) will run on GPU
#             *Expression <Length> length(regexp_replace(text#67,  , , 1)) will run on GPU
#               *Expression <RegExpReplace> regexp_replace(text#67,  , , 1) will run on GPU
#           *Expression <Add> (cast(size(split(text#67,  , -1), true) as double) + 1.0E-6) will run on GPU
#             *Expression <Cast> cast(size(split(text#67,  , -1), true) as double) will run on GPU
#               *Expression <Size> size(split(text#67,  , -1), true) will run on GPU
#                 *Expression <StringSplit> split(text#67,  , -1) will run on GPU
#       *Exec <ProjectExec> will run on GPU
#         *Expression <Alias> concat_ws( , Title#1, CleanBody#59) AS text#67 will run on GPU
#           *Expression <ConcatWs> concat_ws( , Title#1, CleanBody#59) will run on GPU
#         *Expression <Alias> pythonUDF0#203 AS tags_list#77 will run on GPU
#         *Expression <Alias> length(Title#1) AS title_len#87 will run on GPU
#           *Expression <Length> length(Title#1) will run on GPU
#         *Expression <Alias> length(CleanBody#59) AS body_len#98 will run on GPU
#           *Expression <Length> length(CleanBody#59) will run on GPU
#         ! <BatchEvalPythonExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.python.BatchEvalPythonExec
#           @Expression <PythonUDF> clean_tags(Tags#3)#76 could not block GPU acceleration
#             @Expression <AttributeReference> Tags#3 could run on GPU
#           @Expression <AttributeReference> pythonUDF0#203 could run on GPU
#           *Exec <ProjectExec> will run on GPU
#             *Expression <Alias> regexp_replace(Body#2, <.*?>, , 1) AS CleanBody#59 will run on GPU
#               *Expression <RegExpReplace> regexp_replace(Body#2, <.*?>, , 1) will run on GPU
#             *Exec <FilterExec> will run on GPU
#               *Expression <AtLeastNNonNulls> atleastnnonnulls(4, Title#1, Body#2, Tags#3, Y#5) will run on GPU
#               !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 23:33:58 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#282L AS count#283L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:33:58 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#282L AS count#283L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:33:58 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#282L AS count#283L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:04 WARN GpuOverrides:                                (0 + 1) / 1]
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#282L AS count#283L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 23:34:04 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 23:34:04 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#282L AS count#283L will run on GPU
#
# 25/07/22 23:34:04 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#282L AS count#283L will run on GPU
#
# 25/07/22 23:34:04 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#654L AS count#655L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:04 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#654L AS count#655L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:04 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#654L AS count#655L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:08 WARN GpuOverrides:                                (0 + 1) / 1]
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#654L AS count#655L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 23:34:08 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 23:34:08 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#654L AS count#655L will run on GPU
#
# 25/07/22 23:34:08 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#654L AS count#655L will run on GPU
#
# 25/07/22 23:34:08 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1026L AS count#1027L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:08 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1026L AS count#1027L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:08 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1026L AS count#1027L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:08 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1026L AS count#1027L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 23:34:08 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1026L AS count#1027L will run on GPU
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1026L AS count#1027L will run on GPU
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1392L AS count#1393L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1392L AS count#1393L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1392L AS count#1393L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1392L AS count#1393L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1392L AS count#1393L will run on GPU
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1392L AS count#1393L will run on GPU
# Train data count: 35997, Test data count: 9003
#
# --- Logistic Regression Training ---
# 25/07/22 23:34:09 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@503ab451, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1754 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1754 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1756 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1754 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@503ab451, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#1955 could run on GPU
#       @Expression <AttributeReference> buf#1956 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@503ab451, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1754 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1754 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1756 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1754 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@503ab451, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#1955 could run on GPU
#       @Expression <AttributeReference> buf#1956 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 23:34:09 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@503ab451, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1754 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1754 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1756 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1754 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@503ab451, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
# ...
#                   @Expression <Literal> avg_word_len could run on GPU
#                   @Expression <AttributeReference> avg_word_len#123 could run on GPU
#             *Exec <ProjectExec> will run on GPU
#               *Expression <Alias> UDF(UDF(text#67)) AS filtered_words#4483 will run on GPU
#                 *Expression <ScalaUDF> UDF(UDF(text#67)) will run on GPU
#                   *Expression <ScalaUDF> UDF(text#67) will run on GPU
#               *Exec <ProjectExec> will run on GPU
#                 *Expression <Alias> UDF(Y#5) AS label#4440 will run on GPU
#                   *Expression <ScalaUDF> UDF(Y#5) will run on GPU
#                 *Exec <FilterExec> will run on GPU
#                   *Expression <And> (atleastnnonnulls(1, Y#5) AND UDF(Y#5)) will run on GPU
#                     *Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) will run on GPU
#                     *Expression <ScalaUDF> UDF(Y#5) will run on GPU
#                   ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 23:36:34 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <HashPartitioning> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <Alias> knownfloatingpointnormalized(normalizenanandzero(label#4440)) AS label#4440 will run on GPU
#       *Expression <KnownFloatingPointNormalized> knownfloatingpointnormalized(normalizenanandzero(label#4440)) will run on GPU
#         *Expression <NormalizeNaNAndZero> normalizenanandzero(label#4440) will run on GPU
#     *Expression <Alias> knownfloatingpointnormalized(normalizenanandzero(prediction#4807)) AS prediction#4807 will run on GPU
#       *Expression <KnownFloatingPointNormalized> knownfloatingpointnormalized(normalizenanandzero(prediction#4807)) will run on GPU
#         *Expression <NormalizeNaNAndZero> normalizenanandzero(prediction#4807) will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced; unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#4715]
#       @Expression <AttributeReference> label#4440 could run on GPU
#       @Expression <Alias> UDF(UDF(features#4715)) AS prediction#4807 could run on GPU
#         !Expression <ScalaUDF> UDF(UDF(features#4715)) cannot run on GPU because param expression ScalaUDF UDF(features#4715) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#           !Expression <ScalaUDF> UDF(features#4715) cannot run on GPU because param expression AttributeReference features#4715 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(features#4715) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#             !Expression <AttributeReference> features#4715 cannot run on GPU because expression AttributeReference features#4715 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#       !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#4715]; not all expressions can be replaced
#         @Expression <AttributeReference> label#4440 could run on GPU
#         !Expression <Alias> UDF(struct(text_features, UDF(UDF(filtered_words#4483)), bigrams_features, UDF(UDF(UDF(filtered_words#4483))), w2v_features, UDF(filtered_words#4483), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_1e182b98f076, cast(title_len#87 as double), body_len_double_VectorAssembler_1e182b98f076, cast(body_len#98 as double), punct_count_double_VectorAssembler_1e182b98f076, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) AS features#4715 cannot run on GPU because expression Alias UDF(struct(text_features, UDF(UDF(filtered_words#4483)), bigrams_features, UDF(UDF(UDF(filtered_words#4483))), w2v_features, UDF(filtered_words#4483), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_1e182b98f076, cast(title_len#87 as double), body_len_double_VectorAssembler_1e182b98f076, cast(body_len#98 as double), punct_count_double_VectorAssembler_1e182b98f076, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) AS features#4715 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#4483)), bigrams_features, UDF(UDF(UDF(filtered_words#4483))), w2v_features, UDF(filtered_words#4483), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_1e182b98f076, cast(title_len#87 as double), body_len_double_VectorAssembler_1e182b98f076, cast(body_len#98 as double), punct_count_double_VectorAssembler_1e182b98f076, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#           !Expression <ScalaUDF> UDF(struct(text_features, UDF(UDF(filtered_words#4483)), bigrams_features, UDF(UDF(UDF(filtered_words#4483))), w2v_features, UDF(filtered_words#4483), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_1e182b98f076, cast(title_len#87 as double), body_len_double_VectorAssembler_1e182b98f076, cast(body_len#98 as double), punct_count_double_VectorAssembler_1e182b98f076, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) cannot run on GPU because expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#4483)), bigrams_features, UDF(UDF(UDF(filtered_words#4483))), w2v_features, UDF(filtered_words#4483), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_1e182b98f076, cast(title_len#87 as double), body_len_double_VectorAssembler_1e182b98f076, cast(body_len#98 as double), punct_count_double_VectorAssembler_1e182b98f076, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; param expression CreateNamedStruct struct(text_features, UDF(UDF(filtered_words#4483)), bigrams_features, UDF(UDF(UDF(filtered_words#4483))), w2v_features, UDF(filtered_words#4483), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_1e182b98f076, cast(title_len#87 as double), body_len_double_VectorAssembler_1e182b98f076, cast(body_len#98 as double), punct_count_double_VectorAssembler_1e182b98f076, cast(punct_count#110 as double), avg_word_len, avg_word_len#123) (child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#             !Expression <CreateNamedStruct> struct(text_features, UDF(UDF(filtered_words#4483)), bigrams_features, UDF(UDF(UDF(filtered_words#4483))), w2v_features, UDF(filtered_words#4483), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_1e182b98f076, cast(title_len#87 as double), body_len_double_VectorAssembler_1e182b98f076, cast(body_len#98 as double), punct_count_double_VectorAssembler_1e182b98f076, cast(punct_count#110 as double), avg_word_len, avg_word_len#123) cannot run on GPU because value expression ScalaUDF UDF(UDF(UDF(filtered_words#4483))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(tags_list#77)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(filtered_words#4483) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); unsupported data type in output: StructType(StructField(text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(bigrams_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(w2v_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(tags_tags,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(title_len_double_VectorAssembler_1e182b98f076,DoubleType,true),StructField(body_len_double_VectorAssembler_1e182b98f076,DoubleType,true),StructField(punct_count_double_VectorAssembler_1e182b98f076,DoubleType,false),StructField(avg_word_len,DoubleType,true)); value expression ScalaUDF UDF(UDF(filtered_words#4483)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#               @Expression <Literal> text_features could run on GPU
#               !Expression <ScalaUDF> UDF(UDF(filtered_words#4483)) cannot run on GPU because param expression ScalaUDF UDF(filtered_words#4483) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(filtered_words#4483)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 !Expression <ScalaUDF> UDF(filtered_words#4483) cannot run on GPU because expression ScalaUDF UDF(filtered_words#4483) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                   @Expression <AttributeReference> filtered_words#4483 could run on GPU
#               @Expression <Literal> bigrams_features could run on GPU
#               !Expression <ScalaUDF> UDF(UDF(UDF(filtered_words#4483))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(filtered_words#4483))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; param expression ScalaUDF UDF(UDF(filtered_words#4483)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#                 !Expression <ScalaUDF> UDF(UDF(filtered_words#4483)) cannot run on GPU because expression ScalaUDF UDF(UDF(filtered_words#4483)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                   @Expression <ScalaUDF> UDF(filtered_words#4483) could run on GPU
#                     @Expression <AttributeReference> filtered_words#4483 could run on GPU
#               @Expression <Literal> w2v_features could run on GPU
#               !Expression <ScalaUDF> UDF(filtered_words#4483) cannot run on GPU because expression ScalaUDF UDF(filtered_words#4483) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 @Expression <AttributeReference> filtered_words#4483 could run on GPU
#               @Expression <Literal> tags_tags could run on GPU
#               !Expression <ScalaUDF> UDF(UDF(tags_list#77)) cannot run on GPU because param expression ScalaUDF UDF(tags_list#77) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(tags_list#77)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 !Expression <ScalaUDF> UDF(tags_list#77) cannot run on GPU because expression ScalaUDF UDF(tags_list#77) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                   @Expression <AttributeReference> tags_list#77 could run on GPU
#               @Expression <Literal> title_len_double_VectorAssembler_1e182b98f076 could run on GPU
#               @Expression <Cast> cast(title_len#87 as double) could run on GPU
#                 @Expression <AttributeReference> title_len#87 could run on GPU
#               @Expression <Literal> body_len_double_VectorAssembler_1e182b98f076 could run on GPU
#               @Expression <Cast> cast(body_len#98 as double) could run on GPU
#                 @Expression <AttributeReference> body_len#98 could run on GPU
#               @Expression <Literal> punct_count_double_VectorAssembler_1e182b98f076 could run on GPU
#               @Expression <Cast> cast(punct_count#110 as double) could run on GPU
#                 @Expression <AttributeReference> punct_count#110 could run on GPU
#               @Expression <Literal> avg_word_len could run on GPU
#               @Expression <AttributeReference> avg_word_len#123 could run on GPU
#         *Exec <ProjectExec> will run on GPU
#           *Expression <Alias> UDF(UDF(text#67)) AS filtered_words#4483 will run on GPU
#             *Expression <ScalaUDF> UDF(UDF(text#67)) will run on GPU
#               *Expression <ScalaUDF> UDF(text#67) will run on GPU
#           *Exec <ProjectExec> will run on GPU
#             *Expression <Alias> UDF(Y#5) AS label#4440 will run on GPU
#               *Expression <ScalaUDF> UDF(Y#5) will run on GPU
#             *Exec <FilterExec> will run on GPU
#               *Expression <And> (atleastnnonnulls(1, Y#5) AND UDF(Y#5)) will run on GPU
#                 *Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) will run on GPU
#                 *Expression <ScalaUDF> UDF(Y#5) will run on GPU
#               ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
# Logistic Regression Results:
# Accuracy: 0.6920
# F1 Score: 0.6914
# Confusion Matrix:
# 25/07/22 23:36:34 WARN DAGScheduler: Broadcasting large task binary with size 1911.4 KiB
# 25/07/22 23:36:38 WARN GpuOverrides:                                (0 + 1) / 1]
# *Exec <ProjectExec> will run on GPU
#   *Expression <Alias> toprettystring(label#4440, Some(UTC)) AS toprettystring(label)#5437 will run on GPU
#     *Expression <ToPrettyString> toprettystring(label#4440, Some(UTC)) will run on GPU
#   *Expression <Alias> toprettystring(prediction#4807, Some(UTC)) AS toprettystring(prediction)#5438 will run on GPU
#     *Expression <ToPrettyString> toprettystring(prediction#4807, Some(UTC)) will run on GPU
#   *Expression <Alias> toprettystring(count#5430L, Some(UTC)) AS toprettystring(count)#5439 will run on GPU
#     *Expression <ToPrettyString> toprettystring(count#5430L, Some(UTC)) will run on GPU
#   *Exec <SortExec> will run on GPU
#     *Expression <SortOrder> label#4440 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> prediction#4807 ASC NULLS FIRST will run on GPU
#     *Exec <ShuffleExchangeExec> will run on GPU
#       *Partitioning <RangePartitioning> will run on GPU
#         *Expression <SortOrder> label#4440 ASC NULLS FIRST will run on GPU
#         *Expression <SortOrder> prediction#4807 ASC NULLS FIRST will run on GPU
#       *Exec <HashAggregateExec> will run on GPU
#         *Expression <AggregateExpression> count(1) will run on GPU
#           *Expression <Count> count(1) will run on GPU
#         *Expression <Alias> count(1)#5429L AS count#5430L will run on GPU
#
# 25/07/22 23:36:38 WARN GpuOverrides:
# *Exec <TakeOrderedAndProjectExec> will run on GPU
#   *Expression <SortOrder> label#4440 ASC NULLS FIRST will run on GPU
#   *Expression <SortOrder> prediction#4807 ASC NULLS FIRST will run on GPU
#   *Expression <Alias> toprettystring(label#4440, Some(UTC)) AS toprettystring(label)#5437 will run on GPU
#     *Expression <ToPrettyString> toprettystring(label#4440, Some(UTC)) will run on GPU
#   *Expression <Alias> toprettystring(prediction#4807, Some(UTC)) AS toprettystring(prediction)#5438 will run on GPU
#     *Expression <ToPrettyString> toprettystring(prediction#4807, Some(UTC)) will run on GPU
#   *Expression <Alias> toprettystring(count#5430L, Some(UTC)) AS toprettystring(count)#5439 will run on GPU
#     *Expression <ToPrettyString> toprettystring(count#5430L, Some(UTC)) will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     *Expression <Alias> count(1)#5429L AS count#5430L will run on GPU
#     *Exec <AQEShuffleReadExec> will run on GPU
#
# 25/07/22 23:36:39 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  0.0|       0.0| 1918|
# |  0.0|       1.0|  653|
# |  0.0|       2.0|  406|
# |  1.0|       0.0|  854|
# |  1.0|       1.0| 1847|
# |  1.0|       2.0|  279|
# |  2.0|       0.0|  371|
# |  2.0|       1.0|  210|
# |  2.0|       2.0| 2465|
# +-----+----------+-----+
