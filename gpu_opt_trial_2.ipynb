# %%
import re
import traceback
import time
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col, length, concat_ws, regexp_replace, size, split
from pyspark.sql.types import StringType, IntegerType, DoubleType, ArrayType
from pyspark.ml import Pipeline
from pyspark.ml.feature import (
    Tokenizer, StopWordsRemover, HashingTF, IDF, StringIndexer,
    VectorAssembler, NGram, Word2Vec
)
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

def clean_tags(tags):
    if tags is None: return []
    return tags.replace('<', ' ').replace('>', ' ').strip().split()

clean_tags_udf = udf(clean_tags, ArrayType(StringType()))

spark = (SparkSession.builder
    .appName("GPU_IMP_RECOMMENDED")
    .master("local[*]")
    .config("spark.driver.memory","12g")
    .config("spark.executor.memory", "12g")
    .config("spark.executor.cores", "4")
    .config("spark.driver.cores", "4")
    .config("spark.sql.shuffle.partitions", "200")
    .config("spark.plugins", "com.nvidia.spark.SQLPlugin")
    .config("spark.driver.host", "localhost")
    .config("spark.rapids.sql.explain", "DEBUG")
    .config("spark.rapids.sql.allowMultipleJars", "ALWAYS")
    .config("spark.rapids.sql.enabled", "true")
    .config("spark.rapids.memory.hostStorageFraction", "0.8")
    .config("spark.rapids.memory.deviceStorageFraction", "0.8")
    .config("spark.rapids.sql.concurrentGpuTasks", "2")
    .config("spark.memory.offHeap.enabled", "true")
    .config("spark.memory.offHeap.size", "4g")
    .config("spark.rapids.memory.gpu.allocation.limit", "0.9")
    .config("spark.rapids.host.shim.async", "true")
    .config("spark.sql.session.timeZone", "UTC")
    .config("spark.rapids.sql.exec.CollectLimitExec", "true") 
    .config("spark.rapids.sql.rowBasedUDF.enabled", "true")
    # .config("spark.rapids.sql.csv.read.escape.enabled", "true") # Bu, özel kaçış karakterleri için GPU'yu zorlayabilir, ancak test edilmesi gerekir.
    .getOrCreate()
)

data_path = "/mnt/c/Users/BerenÜnveren/Desktop/BIL401/data/train.csv"

try:
    print("--- Data Loading ---")
    start_load_time = time.time()
    df = spark.read.format("csv") \
        .option("header", "true") \
        .option("quote", "\"") \
        .option("escape", "\"") \
        .option("multiLine", "true") \
        .option("inferSchema", "true") \
        .load(data_path)
    load_time = time.time() - start_load_time
    print(f"Data load time: {load_time:.2f} seconds")

    print("data schema:")
    df.printSchema()
    print("Y column distribution after load (should be HQ, LQ_EDIT, LQ_CLOSE):")
    df.groupBy("Y").count().show()

    print("--- Data Cleaning and Feature Engineering (initial steps) ---")
    start_clean_feature_time = time.time()
    df_clean = df.na.drop(subset=["Title", "Body", "Tags", "Y"]) \
        .withColumn("CleanBody", regexp_replace(col("Body"), "<.*?>", "")) \
        .withColumn("text", concat_ws(" ", col("Title"), col("CleanBody"))) \
        .withColumn("tags_list", clean_tags_udf(col("Tags"))) # Bu UDF hala CPU'da çalışacak

    df_featured = df_clean.withColumn("title_len", length(col("Title"))) \
        .withColumn("body_len", length(col("CleanBody"))) \
        .withColumn("punct_count", length(col("text")) - length(regexp_replace(col("text"), "[?!]", ""))) \
        .withColumn("avg_word_len", length(regexp_replace(col("text"), " ", "")) / (size(split(col("text"), " ")) + 1e-6))
    clean_feature_time = time.time() - start_clean_feature_time
    print(f"Initial data cleaning and feature engineering time: {clean_feature_time:.2f} seconds")

    # StringIndexer, Tokenizer, StopWordsRemover, HashingTF, IDF, NGram, Word2Vec, VectorAssembler
    # gibi MLlib özellik transformatörlerinin çoğu, RAPIDS tarafından tam GPU hızlandırmasına sahip değildir
    # veya VectorUDT gibi desteklenmeyen tipler nedeniyle CPU'ya geri döner.
    # Bu adımlar GPU'da çalışmadığı için bellek sorunlarına neden olabilir.
except Exception as e:
    print(f"An error occurred: {e}")
    traceback.print_exc()
# Out:
# 25/07/22 22:31:39 WARN Utils: Your hostname, DESKTOP-15VE119 resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/07/22 22:31:39 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/07/22 22:31:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/07/22 22:31:41 WARN RapidsPluginUtils: RAPIDS Accelerator 24.02.0 using cudf 24.02.1.
# 25/07/22 22:31:41 WARN RapidsPluginUtils: spark.rapids.sql.multiThreadedRead.numThreads is set to 20.
# 25/07/22 22:31:41 WARN RapidsPluginUtils: Multiple cudf jars found in the classpath:
# revison: dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/rapids-4-spark_2.12-24.02.0.jar
# 	version=24.02.1
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T05:34:16Z
# 	url=https://github.com/rapidsai/cudf.git
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/cudf-24.02.2-cuda12.jar
# 	version=24.02.2
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T07:51:45Z
# Please make sure there is only one cudf jar in the classpath.
# 25/07/22 22:31:41 WARN RapidsPluginUtils: RAPIDS Accelerator is enabled, to disable GPU support set `spark.rapids.sql.enabled` to false.
# 25/07/22 22:31:41 WARN RapidsPluginUtils: spark.rapids.sql.explain is set to `DEBUG`. Set it to 'NONE' to suppress the diagnostics logging about the query placement on the GPU.
# 25/07/22 22:31:52 WARN RapidsPluginUtils: Multiple cudf jars found in the classpath:
# revison: dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/rapids-4-spark_2.12-24.02.0.jar
# 	version=24.02.1
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T05:34:16Z
# 	url=https://github.com/rapidsai/cudf.git
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/cudf-24.02.2-cuda12.jar
# 	version=24.02.2
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T07:51:45Z
# Please make sure there is only one cudf jar in the classpath.
# 25/07/22 22:31:53 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# 25/07/22 22:31:53 ERROR Inbox: Ignoring error
# java.lang.NullPointerException: Cannot invoke "org.apache.spark.storage.BlockManagerId.executorId()" because "idWithoutTopologyInfo" is null
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:677)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# 25/07/22 22:31:53 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:358)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# Caused by: java.lang.NullPointerException: Cannot invoke "org.apache.spark.storage.BlockManagerId.executorId()" because "idWithoutTopologyInfo" is null
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:677)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# --- Data Loading ---
# Data load time: 4.75 seconds
# data schema:
# root
#  |-- Id: integer (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Body: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- CreationDate: timestamp (nullable = true)
#  |-- Y: string (nullable = true)
#
# Y column distribution after load (should be HQ, LQ_EDIT, LQ_CLOSE):
# 25/07/22 22:32:00 WARN GpuOverrides:
#         !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 22:32:00 WARN GpuOverrides:
#         !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 22:32:00 WARN GpuOverrides:
#         !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 22:32:00 WARN GpuOverrides:
#     !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
# +--------+-----+
# |       Y|count|
# +--------+-----+
# |LQ_CLOSE|15000|
# |      HQ|15000|
# | LQ_EDIT|15000|
# +--------+-----+
#
# --- Data Cleaning and Feature Engineering (initial steps) ---
# Initial data cleaning and feature engineering time: 0.22 seconds
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 33508)
# Traceback (most recent call last):
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/socketserver.py", line 316, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/socketserver.py", line 347, in process_request
#     self.finish_request(request, client_address)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/socketserver.py", line 360, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/socketserver.py", line 747, in __init__
#     self.handle()
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/accumulators.py", line 295, in handle
#     poll(accum_updates)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/accumulators.py", line 267, in poll
#     if self.rfile in r and func():
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/accumulators.py", line 271, in accum_updates
#     num_updates = read_int(self.rfile)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------

# %%
try:
    label_indexer = StringIndexer(inputCol="Y", outputCol="label", handleInvalid="skip")
    tokenizer = Tokenizer(inputCol="text", outputCol="words")
    stopwords_remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")
    ngram = NGram(n=2, inputCol="filtered_words", outputCol="bigrams")

    hashing_tf_text = HashingTF(inputCol="filtered_words", outputCol="raw_text_features", numFeatures=20000)
    idf_text = IDF(inputCol="raw_text_features", outputCol="text_features")

    hashing_tf_bigrams = HashingTF(inputCol="bigrams", outputCol="raw_bigrams_features", numFeatures=20000)
    idf_bigrams = IDF(inputCol="raw_bigrams_features", outputCol="bigrams_features")

    w2v = Word2Vec(vectorSize=100, minCount=5, inputCol="filtered_words", outputCol="w2v_features")

    hashing_tf_tags = HashingTF(inputCol="tags_list", outputCol="raw_tags_features", numFeatures=5000)
    idf_tags = IDF(inputCol="raw_tags_features", outputCol="tags_tags")

    feature_assembler = VectorAssembler(
        inputCols=["text_features", "bigrams_features", "w2v_features", "tags_tags",
                   "title_len", "body_len", "punct_count", "avg_word_len"],
        outputCol="features"
    )

    (train_data, test_data) = df_featured.randomSplit([0.8, 0.2], seed=42)
    train_data.cache(); test_data.cache()
    print(f"Train data count: {train_data.count()}, Test data count: {test_data.count()}")
except Exception as e:
    print(f"An error occurred: {e}")
    traceback.print_exc()
# Out:
# 25/07/22 22:32:04 WARN GpuOverrides:
#         ! <BatchEvalPythonExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.python.BatchEvalPythonExec
#           @Expression <PythonUDF> clean_tags(Tags#3)#76 could not block GPU acceleration
#             @Expression <AttributeReference> Tags#3 could run on GPU
#           @Expression <AttributeReference> pythonUDF0#137 could run on GPU
#               !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 22:32:05 WARN GpuOverrides:
#         ! <BatchEvalPythonExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.python.BatchEvalPythonExec
#           @Expression <PythonUDF> clean_tags(Tags#3)#76 could not block GPU acceleration
#             @Expression <AttributeReference> Tags#3 could run on GPU
#           @Expression <AttributeReference> pythonUDF0#203 could run on GPU
#               !Exec <FileSourceScanExec> cannot run on GPU because GpuCSVScan does not support modified escape chars
#
# 25/07/22 22:32:05 WARN GpuOverrides:
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 22:32:05 WARN GpuOverrides:
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 22:32:05 WARN GpuOverrides:
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 22:32:10 WARN GpuOverrides:                                (0 + 1) / 1]
#       ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:32:10 WARN GpuOverrides:
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:32:10 WARN GpuOverrides:
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 22:32:10 WARN GpuOverrides:
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/07/22 22:32:10 WARN GpuOverrides:
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# [Stage 9:>                                                          (0 + 1) / 1]
# Train data count: 35997, Test data count: 9003
# 25/07/22 22:32:15 WARN GpuOverrides:
#       ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:32:15 WARN GpuOverrides:
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec

# %%
try:
    print("\n--- Logistic Regression Training ---")
    lr = LogisticRegression(featuresCol="features", labelCol="label", maxIter=10)
    lr_pipeline = Pipeline(stages=[
        label_indexer, tokenizer, stopwords_remover, ngram,
        hashing_tf_text, idf_text, hashing_tf_bigrams, idf_bigrams, w2v, hashing_tf_tags, idf_tags,
        feature_assembler, lr
    ])

    start_lr_train_time = time.time()
    lr_model = lr_pipeline.fit(train_data)
    lr_train_time = time.time() - start_lr_train_time
    print(f"Logistic Regression training time: {lr_train_time:.2f} seconds")

    start_lr_predict_time = time.time()
    lr_predictions = lr_model.transform(test_data)
    lr_predict_time = time.time() - start_lr_predict_time
    print(f"Logistic Regression prediction time: {lr_predict_time:.2f} seconds")

    evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction")
    accuracy_lr = evaluator.setMetricName("accuracy").evaluate(lr_predictions)
    f1_score_lr = evaluator.setMetricName("f1").evaluate(lr_predictions)

    print("\nLogistic Regression Results:")
    print(f"Accuracy: {accuracy_lr:.4f}")
    print(f"F1 Score: {f1_score_lr:.4f}")
    print("Confusion Matrix:")
    lr_predictions.groupBy("label", "prediction").count().orderBy("label", "prediction").show()
except Exception as e:
    print(f"An error occurred: {e}")
    traceback.print_exc()
# Out:
# --- Logistic Regression Training ---
# 25/07/22 22:32:15 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1024 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#1223 could run on GPU
#       @Expression <AttributeReference> buf#1224 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:32:15 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1024 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#1223 could run on GPU
#       @Expression <AttributeReference> buf#1224 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:32:15 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1024 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#1223 could run on GPU
#       @Expression <AttributeReference> buf#1224 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:32:15 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1024 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#1223 could run on GPU
#       @Expression <AttributeReference> buf#1224 could run on GPU
#       ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:32:15 WARN GpuOverrides:
# !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#   @Partitioning <SinglePartition$> could run on GPU
#   !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#     @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#       ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#         ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#           ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#             @Expression <AttributeReference> Y#5 could run on GPU
#         ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#           ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#         ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#           ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#         ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#           ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#     @Expression <AttributeReference> buf#1223 could run on GPU
#     @Expression <AttributeReference> buf#1224 could run on GPU
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:32:16 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1024 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#
# 25/07/22 22:32:16 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@33b4900c, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1024 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1022 could run on GPU
#
# 25/07/22 22:32:16 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize, StructField(raw_text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <Invoke> newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#       ! <NewInstance> newInstance(class org.apache.spark.ml.linalg.VectorUDT) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.NewInstance
#       !Expression <AttributeReference> raw_text_features#1475 cannot run on GPU because expression AttributeReference raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#   !Expression <AttributeReference> obj#1495 cannot run on GPU because expression AttributeReference obj#1495 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [raw_text_features#1475]; not all expressions can be replaced
#     !Expression <Alias> UDF(UDF(UDF(text#67))) AS raw_text_features#1475 cannot run on GPU because expression Alias UDF(UDF(UDF(text#67))) AS raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(UDF(UDF(text#67))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#       !Expression <ScalaUDF> UDF(UDF(UDF(text#67))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(text#67))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <ScalaUDF> UDF(UDF(text#67)) could run on GPU
#           @Expression <ScalaUDF> UDF(text#67) could run on GPU
#             @Expression <AttributeReference> text#67 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#         @Expression <AttributeReference> text#67 could run on GPU
#         @Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) could run on GPU
#           @Expression <AttributeReference> Y#5 could run on GPU
#         @Expression <ScalaUDF> UDF(Y#5) could run on GPU
#           @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:32:16 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize, StructField(raw_text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <Invoke> newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#       ! <NewInstance> newInstance(class org.apache.spark.ml.linalg.VectorUDT) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.NewInstance
#       !Expression <AttributeReference> raw_text_features#1475 cannot run on GPU because expression AttributeReference raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#   !Expression <AttributeReference> obj#1495 cannot run on GPU because expression AttributeReference obj#1495 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [raw_text_features#1475]; not all expressions can be replaced
#     !Expression <Alias> UDF(UDF(UDF(text#67))) AS raw_text_features#1475 cannot run on GPU because expression Alias UDF(UDF(UDF(text#67))) AS raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(UDF(UDF(text#67))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#       !Expression <ScalaUDF> UDF(UDF(UDF(text#67))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(text#67))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <ScalaUDF> UDF(UDF(text#67)) could run on GPU
#           @Expression <ScalaUDF> UDF(text#67) could run on GPU
#             @Expression <AttributeReference> text#67 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#         @Expression <AttributeReference> text#67 could run on GPU
#         @Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) could run on GPU
#           @Expression <AttributeReference> Y#5 could run on GPU
#         @Expression <ScalaUDF> UDF(Y#5) could run on GPU
#           @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:32:16 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize, StructField(raw_text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <Invoke> newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#       ! <NewInstance> newInstance(class org.apache.spark.ml.linalg.VectorUDT) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.NewInstance
#       !Expression <AttributeReference> raw_text_features#1475 cannot run on GPU because expression AttributeReference raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#   !Expression <AttributeReference> obj#1495 cannot run on GPU because expression AttributeReference obj#1495 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [raw_text_features#1475]; not all expressions can be replaced
#     !Expression <Alias> UDF(UDF(UDF(text#67))) AS raw_text_features#1475 cannot run on GPU because expression Alias UDF(UDF(UDF(text#67))) AS raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(UDF(UDF(text#67))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#       !Expression <ScalaUDF> UDF(UDF(UDF(text#67))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(text#67))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <ScalaUDF> UDF(UDF(text#67)) could run on GPU
#           @Expression <ScalaUDF> UDF(text#67) could run on GPU
#             @Expression <AttributeReference> text#67 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#         @Expression <AttributeReference> text#67 could run on GPU
#         @Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) could run on GPU
#           @Expression <AttributeReference> Y#5 could run on GPU
#         @Expression <ScalaUDF> UDF(Y#5) could run on GPU
#           @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:32:16 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize, StructField(raw_text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <Invoke> newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#       ! <NewInstance> newInstance(class org.apache.spark.ml.linalg.VectorUDT) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.NewInstance
#       !Expression <AttributeReference> raw_text_features#1475 cannot run on GPU because expression AttributeReference raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#   !Expression <AttributeReference> obj#1495 cannot run on GPU because expression AttributeReference obj#1495 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [raw_text_features#1475]; not all expressions can be replaced
#     !Expression <Alias> UDF(UDF(UDF(text#67))) AS raw_text_features#1475 cannot run on GPU because expression Alias UDF(UDF(UDF(text#67))) AS raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(UDF(UDF(text#67))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#       !Expression <ScalaUDF> UDF(UDF(UDF(text#67))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(text#67))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <ScalaUDF> UDF(UDF(text#67)) could run on GPU
#           @Expression <ScalaUDF> UDF(text#67) could run on GPU
#             @Expression <AttributeReference> text#67 could run on GPU
#       ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:32:16 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize, StructField(raw_text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <Invoke> newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#       ! <NewInstance> newInstance(class org.apache.spark.ml.linalg.VectorUDT) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.NewInstance
#       !Expression <AttributeReference> raw_text_features#1475 cannot run on GPU because expression AttributeReference raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#   !Expression <AttributeReference> obj#1495 cannot run on GPU because expression AttributeReference obj#1495 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [raw_text_features#1475]; not all expressions can be replaced
#     !Expression <Alias> UDF(UDF(UDF(text#67))) AS raw_text_features#1475 cannot run on GPU because expression Alias UDF(UDF(UDF(text#67))) AS raw_text_features#1475 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(UDF(UDF(text#67))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#       !Expression <ScalaUDF> UDF(UDF(UDF(text#67))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(text#67))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
# ...
#                   @Expression <Literal> text_features could run on GPU
#                   !Expression <ScalaUDF> UDF(UDF(filtered_words#3751)) cannot run on GPU because param expression ScalaUDF UDF(filtered_words#3751) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(filtered_words#3751)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                     !Expression <ScalaUDF> UDF(filtered_words#3751) cannot run on GPU because expression ScalaUDF UDF(filtered_words#3751) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                       @Expression <AttributeReference> filtered_words#3751 could run on GPU
#                   @Expression <Literal> bigrams_features could run on GPU
#                   !Expression <ScalaUDF> UDF(UDF(UDF(filtered_words#3751))) cannot run on GPU because param expression ScalaUDF UDF(UDF(filtered_words#3751)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(UDF(filtered_words#3751))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                     !Expression <ScalaUDF> UDF(UDF(filtered_words#3751)) cannot run on GPU because expression ScalaUDF UDF(UDF(filtered_words#3751)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                       @Expression <ScalaUDF> UDF(filtered_words#3751) could run on GPU
#                         @Expression <AttributeReference> filtered_words#3751 could run on GPU
#                   @Expression <Literal> w2v_features could run on GPU
#                   !Expression <ScalaUDF> UDF(filtered_words#3751) cannot run on GPU because expression ScalaUDF UDF(filtered_words#3751) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                     @Expression <AttributeReference> filtered_words#3751 could run on GPU
#                   @Expression <Literal> tags_tags could run on GPU
#                   !Expression <ScalaUDF> UDF(UDF(tags_list#77)) cannot run on GPU because param expression ScalaUDF UDF(tags_list#77) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(tags_list#77)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                     !Expression <ScalaUDF> UDF(tags_list#77) cannot run on GPU because expression ScalaUDF UDF(tags_list#77) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                       @Expression <AttributeReference> tags_list#77 could run on GPU
#                   @Expression <Literal> title_len_double_VectorAssembler_b2c93055655c could run on GPU
#                   @Expression <Cast> cast(title_len#87 as double) could run on GPU
#                     @Expression <AttributeReference> title_len#87 could run on GPU
#                   @Expression <Literal> body_len_double_VectorAssembler_b2c93055655c could run on GPU
#                   @Expression <Cast> cast(body_len#98 as double) could run on GPU
#                     @Expression <AttributeReference> body_len#98 could run on GPU
#                   @Expression <Literal> punct_count_double_VectorAssembler_b2c93055655c could run on GPU
#                   @Expression <Cast> cast(punct_count#110 as double) could run on GPU
#                     @Expression <AttributeReference> punct_count#110 could run on GPU
#                   @Expression <Literal> avg_word_len could run on GPU
#                   @Expression <AttributeReference> avg_word_len#123 could run on GPU
#                   ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:34:34 WARN GpuOverrides:
#     !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced; unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#3983]
#       @Expression <AttributeReference> label#3708 could run on GPU
#       @Expression <Alias> UDF(UDF(features#3983)) AS prediction#4075 could run on GPU
#         !Expression <ScalaUDF> UDF(UDF(features#3983)) cannot run on GPU because param expression ScalaUDF UDF(features#3983) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#           !Expression <ScalaUDF> UDF(features#3983) cannot run on GPU because expression ScalaUDF UDF(features#3983) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; param expression AttributeReference features#3983 (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#             !Expression <AttributeReference> features#3983 cannot run on GPU because expression AttributeReference features#3983 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#       !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#3983]; not all expressions can be replaced
#         @Expression <AttributeReference> label#3708 could run on GPU
#         !Expression <Alias> UDF(struct(text_features, UDF(UDF(filtered_words#3751)), bigrams_features, UDF(UDF(UDF(filtered_words#3751))), w2v_features, UDF(filtered_words#3751), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) AS features#3983 cannot run on GPU because expression Alias UDF(struct(text_features, UDF(UDF(filtered_words#3751)), bigrams_features, UDF(UDF(UDF(filtered_words#3751))), w2v_features, UDF(filtered_words#3751), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) AS features#3983 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#3751)), bigrams_features, UDF(UDF(UDF(filtered_words#3751))), w2v_features, UDF(filtered_words#3751), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#           !Expression <ScalaUDF> UDF(struct(text_features, UDF(UDF(filtered_words#3751)), bigrams_features, UDF(UDF(UDF(filtered_words#3751))), w2v_features, UDF(filtered_words#3751), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) cannot run on GPU because expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#3751)), bigrams_features, UDF(UDF(UDF(filtered_words#3751))), w2v_features, UDF(filtered_words#3751), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; param expression CreateNamedStruct struct(text_features, UDF(UDF(filtered_words#3751)), bigrams_features, UDF(UDF(UDF(filtered_words#3751))), w2v_features, UDF(filtered_words#3751), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123) (child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#             !Expression <CreateNamedStruct> struct(text_features, UDF(UDF(filtered_words#3751)), bigrams_features, UDF(UDF(UDF(filtered_words#3751))), w2v_features, UDF(filtered_words#3751), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123) cannot run on GPU because unsupported data type in output: StructType(StructField(text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(bigrams_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(w2v_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(tags_tags,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(title_len_double_VectorAssembler_b2c93055655c,DoubleType,true),StructField(body_len_double_VectorAssembler_b2c93055655c,DoubleType,true),StructField(punct_count_double_VectorAssembler_b2c93055655c,DoubleType,false),StructField(avg_word_len,DoubleType,true)); value expression ScalaUDF UDF(UDF(filtered_words#3751)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(UDF(filtered_words#3751))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(tags_list#77)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(filtered_words#3751) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#               @Expression <Literal> text_features could run on GPU
#               !Expression <ScalaUDF> UDF(UDF(filtered_words#3751)) cannot run on GPU because param expression ScalaUDF UDF(filtered_words#3751) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(filtered_words#3751)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 !Expression <ScalaUDF> UDF(filtered_words#3751) cannot run on GPU because expression ScalaUDF UDF(filtered_words#3751) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                   @Expression <AttributeReference> filtered_words#3751 could run on GPU
#               @Expression <Literal> bigrams_features could run on GPU
#               !Expression <ScalaUDF> UDF(UDF(UDF(filtered_words#3751))) cannot run on GPU because param expression ScalaUDF UDF(UDF(filtered_words#3751)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(UDF(filtered_words#3751))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 !Expression <ScalaUDF> UDF(UDF(filtered_words#3751)) cannot run on GPU because expression ScalaUDF UDF(UDF(filtered_words#3751)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                   @Expression <ScalaUDF> UDF(filtered_words#3751) could run on GPU
#                     @Expression <AttributeReference> filtered_words#3751 could run on GPU
#               @Expression <Literal> w2v_features could run on GPU
#               !Expression <ScalaUDF> UDF(filtered_words#3751) cannot run on GPU because expression ScalaUDF UDF(filtered_words#3751) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 @Expression <AttributeReference> filtered_words#3751 could run on GPU
#               @Expression <Literal> tags_tags could run on GPU
#               !Expression <ScalaUDF> UDF(UDF(tags_list#77)) cannot run on GPU because param expression ScalaUDF UDF(tags_list#77) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(tags_list#77)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 !Expression <ScalaUDF> UDF(tags_list#77) cannot run on GPU because expression ScalaUDF UDF(tags_list#77) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                   @Expression <AttributeReference> tags_list#77 could run on GPU
#               @Expression <Literal> title_len_double_VectorAssembler_b2c93055655c could run on GPU
#               @Expression <Cast> cast(title_len#87 as double) could run on GPU
#                 @Expression <AttributeReference> title_len#87 could run on GPU
#               @Expression <Literal> body_len_double_VectorAssembler_b2c93055655c could run on GPU
#               @Expression <Cast> cast(body_len#98 as double) could run on GPU
#                 @Expression <AttributeReference> body_len#98 could run on GPU
#               @Expression <Literal> punct_count_double_VectorAssembler_b2c93055655c could run on GPU
#               @Expression <Cast> cast(punct_count#110 as double) could run on GPU
#                 @Expression <AttributeReference> punct_count#110 could run on GPU
#               @Expression <Literal> avg_word_len could run on GPU
#               @Expression <AttributeReference> avg_word_len#123 could run on GPU
#               ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
# Logistic Regression Results:
# Accuracy: 0.6918
# F1 Score: 0.6911
# Confusion Matrix:
# 25/07/22 22:34:34 WARN DAGScheduler: Broadcasting large task binary with size 1911.4 KiB
# [Stage 41:>                                                         (0 + 1) / 1]
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  0.0|       0.0| 1915|
# |  0.0|       1.0|  666|
# |  0.0|       2.0|  396|
# |  1.0|       0.0|  864|
# |  1.0|       1.0| 1840|
# |  1.0|       2.0|  276|
# |  2.0|       0.0|  368|
# |  2.0|       1.0|  205|
# |  2.0|       2.0| 2473|
# +-----+----------+-----+
# 25/07/22 22:34:38 WARN DAGScheduler: Broadcasting large task binary with size 4.6 MiB

# %%
try:
    print("\n--- Random Forest Training with Cross-Validation ---")
    # çoklu-GPU Dask üzerinden desteklenir. CPU geri dönüşleri hala bir darboğazdır.
    rf = RandomForestClassifier(featuresCol="features", labelCol="label", seed=42)
    rf_pipeline = Pipeline(stages=[
        label_indexer, tokenizer, stopwords_remover, ngram,
        hashing_tf_text, idf_text, hashing_tf_bigrams, idf_bigrams, w2v, hashing_tf_tags, idf_tags,
        feature_assembler, rf
    ])

    paramGrid = ParamGridBuilder() \
        .addGrid(rf.numTrees, [50, 100]) \
        .addGrid(rf.maxDepth, [5, 10]) \
        .build()

    crossval = CrossValidator(estimator=rf_pipeline,
                              estimatorParamMaps=paramGrid,
                              evaluator=MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="f1"),
                              numFolds=3)

    start_rf_train_time = time.time()
    cv_model = crossval.fit(train_data)
    rf_train_time = time.time() - start_rf_train_time
    print(f"Random Forest training (with CV) time: {rf_train_time:.2f} seconds")

    best_rf_model = cv_model.bestModel
    start_rf_predict_time = time.time()
    rf_predictions = best_rf_model.transform(test_data)
    rf_predict_time = time.time() - start_rf_predict_time
    print(f"Random Forest prediction time: {rf_predict_time:.2f} seconds")

    accuracy_rf = evaluator.setMetricName("accuracy").evaluate(rf_predictions)
    f1_score_rf = evaluator.setMetricName("f1").evaluate(rf_predictions)

    print("\nRandom Forest Results:")
    print(f"Accuracy: {accuracy_rf:.4f}")
    print(f"F1 Score: {f1_score_rf:.4f}")

    best_params_stage = best_rf_model.stages[-1]
    print(f"Best parameters: numTrees={best_params_stage.getNumTrees()}, maxDepth={best_params_stage.getMaxDepth()}")

    print("Confusion Matrix:")
    rf_predictions.groupBy("label", "prediction").count().orderBy("label", "prediction").show()
except Exception as e:
    print(f"An error occurred: {e}")
    traceback.print_exc()
finally:
    try:
        spark.stop()
    except Exception as e:
        print(f"Error stopping Spark session: {e}")
        traceback.print_exc()
# Out:
# --- Random Forest Training with Cross-Validation ---
# 25/07/22 22:34:38 WARN GpuOverrides:
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#       @Expression <AttributeReference> Body#2 could run on GPU
#       @Expression <AttributeReference> CleanBody#59 could run on GPU
#       @Expression <AttributeReference> CreationDate#4 could run on GPU
#       @Expression <AttributeReference> Id#0 could run on GPU
#       @Expression <AttributeReference> Tags#3 could run on GPU
#       @Expression <AttributeReference> Title#1 could run on GPU
#       @Expression <AttributeReference> Y#5 could run on GPU
#       @Expression <AttributeReference> avg_word_len#123 could run on GPU
#       @Expression <AttributeReference> body_len#98 could run on GPU
#       @Expression <AttributeReference> punct_count#110 could run on GPU
#       @Expression <AttributeReference> tags_list#77 could run on GPU
#       @Expression <AttributeReference> text#67 could run on GPU
#       @Expression <AttributeReference> title_len#87 could run on GPU
#
# 25/07/22 22:34:38 WARN GpuOverrides:
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#       @Expression <AttributeReference> Body#2 could run on GPU
#       @Expression <AttributeReference> CleanBody#59 could run on GPU
#       @Expression <AttributeReference> CreationDate#4 could run on GPU
#       @Expression <AttributeReference> Id#0 could run on GPU
#       @Expression <AttributeReference> Tags#3 could run on GPU
#       @Expression <AttributeReference> Title#1 could run on GPU
#       @Expression <AttributeReference> Y#5 could run on GPU
#       @Expression <AttributeReference> avg_word_len#123 could run on GPU
#       @Expression <AttributeReference> body_len#98 could run on GPU
#       @Expression <AttributeReference> punct_count#110 could run on GPU
#       @Expression <AttributeReference> tags_list#77 could run on GPU
#       @Expression <AttributeReference> text#67 could run on GPU
#       @Expression <AttributeReference> title_len#87 could run on GPU
#
# 25/07/22 22:34:38 WARN GpuOverrides:
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#       @Expression <AttributeReference> Body#2 could run on GPU
#       @Expression <AttributeReference> CleanBody#59 could run on GPU
#       @Expression <AttributeReference> CreationDate#4 could run on GPU
#       @Expression <AttributeReference> Id#0 could run on GPU
#       @Expression <AttributeReference> Tags#3 could run on GPU
#       @Expression <AttributeReference> Title#1 could run on GPU
#       @Expression <AttributeReference> Y#5 could run on GPU
#       @Expression <AttributeReference> avg_word_len#123 could run on GPU
#       @Expression <AttributeReference> body_len#98 could run on GPU
#       @Expression <AttributeReference> punct_count#110 could run on GPU
#       @Expression <AttributeReference> tags_list#77 could run on GPU
#       @Expression <AttributeReference> text#67 could run on GPU
#       @Expression <AttributeReference> title_len#87 could run on GPU
#
# 25/07/22 22:34:38 WARN GpuOverrides:
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#       @Expression <AttributeReference> Body#2 could run on GPU
#       @Expression <AttributeReference> CleanBody#59 could run on GPU
#       @Expression <AttributeReference> CreationDate#4 could run on GPU
#       @Expression <AttributeReference> Id#0 could run on GPU
#       @Expression <AttributeReference> Tags#3 could run on GPU
#       @Expression <AttributeReference> Title#1 could run on GPU
#       @Expression <AttributeReference> Y#5 could run on GPU
#       @Expression <AttributeReference> avg_word_len#123 could run on GPU
#       @Expression <AttributeReference> body_len#98 could run on GPU
#       @Expression <AttributeReference> punct_count#110 could run on GPU
#       @Expression <AttributeReference> tags_list#77 could run on GPU
#       @Expression <AttributeReference> text#67 could run on GPU
#       @Expression <AttributeReference> title_len#87 could run on GPU
#
# 25/07/22 22:34:38 WARN GpuOverrides:
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#       @Expression <AttributeReference> Body#2 could run on GPU
#       @Expression <AttributeReference> CleanBody#59 could run on GPU
#       @Expression <AttributeReference> CreationDate#4 could run on GPU
#       @Expression <AttributeReference> Id#0 could run on GPU
#       @Expression <AttributeReference> Tags#3 could run on GPU
#       @Expression <AttributeReference> Title#1 could run on GPU
#       @Expression <AttributeReference> Y#5 could run on GPU
#       @Expression <AttributeReference> avg_word_len#123 could run on GPU
#       @Expression <AttributeReference> body_len#98 could run on GPU
#       @Expression <AttributeReference> punct_count#110 could run on GPU
#       @Expression <AttributeReference> tags_list#77 could run on GPU
#       @Expression <AttributeReference> text#67 could run on GPU
#       @Expression <AttributeReference> title_len#87 could run on GPU
#
# 25/07/22 22:34:38 WARN GpuOverrides:
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#       @Expression <AttributeReference> Body#2 could run on GPU
#       @Expression <AttributeReference> CleanBody#59 could run on GPU
#       @Expression <AttributeReference> CreationDate#4 could run on GPU
#       @Expression <AttributeReference> Id#0 could run on GPU
#       @Expression <AttributeReference> Tags#3 could run on GPU
#       @Expression <AttributeReference> Title#1 could run on GPU
#       @Expression <AttributeReference> Y#5 could run on GPU
#       @Expression <AttributeReference> avg_word_len#123 could run on GPU
#       @Expression <AttributeReference> body_len#98 could run on GPU
#       @Expression <AttributeReference> punct_count#110 could run on GPU
#       @Expression <AttributeReference> tags_list#77 could run on GPU
#       @Expression <AttributeReference> text#67 could run on GPU
#       @Expression <AttributeReference> title_len#87 could run on GPU
#
# 25/07/22 22:34:38 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 AS StringIndexerAggregator(org.apache.spark.sql.Row)#5620 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#5834 could run on GPU
#       @Expression <AttributeReference> buf#5835 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:34:39 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 AS StringIndexerAggregator(org.apache.spark.sql.Row)#5620 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#5834 could run on GPU
#       @Expression <AttributeReference> buf#5835 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:34:39 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 AS StringIndexerAggregator(org.apache.spark.sql.Row)#5620 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#5834 could run on GPU
#       @Expression <AttributeReference> buf#5835 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:34:39 WARN GpuOverrides:
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#       @Expression <AttributeReference> Body#2 could run on GPU
#       @Expression <AttributeReference> CleanBody#59 could run on GPU
#       @Expression <AttributeReference> CreationDate#4 could run on GPU
#       @Expression <AttributeReference> Id#0 could run on GPU
#       @Expression <AttributeReference> Tags#3 could run on GPU
#       @Expression <AttributeReference> Title#1 could run on GPU
#       @Expression <AttributeReference> Y#5 could run on GPU
#       @Expression <AttributeReference> avg_word_len#123 could run on GPU
#       @Expression <AttributeReference> body_len#98 could run on GPU
#       @Expression <AttributeReference> punct_count#110 could run on GPU
#       @Expression <AttributeReference> tags_list#77 could run on GPU
#       @Expression <AttributeReference> text#67 could run on GPU
#       @Expression <AttributeReference> title_len#87 could run on GPU
#
# 25/07/22 22:34:39 WARN GpuOverrides:
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:34:39 WARN GpuOverrides:
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:34:39 WARN GpuOverrides:                                (0 + 1) / 1]
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 AS StringIndexerAggregator(org.apache.spark.sql.Row)#5620 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#5834 could run on GPU
#       @Expression <AttributeReference> buf#5835 could run on GPU
#       ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:34:39 WARN GpuOverrides:
# !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#   @Partitioning <SinglePartition$> could run on GPU
#   !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#     @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#       ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#         ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#           ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#             @Expression <AttributeReference> Y#5 could run on GPU
#         ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#           ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#         ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#           ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#         ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#           ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#     @Expression <AttributeReference> buf#5834 could run on GPU
#     @Expression <AttributeReference> buf#5835 could run on GPU
#     ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:34:40 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 AS StringIndexerAggregator(org.apache.spark.sql.Row)#5620 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#
# 25/07/22 22:34:40 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@3dd676de, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 AS StringIndexerAggregator(org.apache.spark.sql.Row)#5620 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#5618 could run on GPU
#
# 25/07/22 22:34:40 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize, StructField(raw_text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <Invoke> newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#       ! <NewInstance> newInstance(class org.apache.spark.ml.linalg.VectorUDT) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.NewInstance
#       !Expression <AttributeReference> raw_text_features#6166 cannot run on GPU because expression AttributeReference raw_text_features#6166 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#   !Expression <AttributeReference> obj#6187 cannot run on GPU because expression AttributeReference obj#6187 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [raw_text_features#6166]
#     !Expression <Alias> UDF(UDF(UDF(text#67))) AS raw_text_features#6166 cannot run on GPU because expression Alias UDF(UDF(UDF(text#67))) AS raw_text_features#6166 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(UDF(UDF(text#67))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#       !Expression <ScalaUDF> UDF(UDF(UDF(text#67))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(text#67))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <ScalaUDF> UDF(UDF(text#67)) could run on GPU
#           @Expression <ScalaUDF> UDF(text#67) could run on GPU
#             @Expression <AttributeReference> text#67 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#         @Expression <AttributeReference> text#67 could run on GPU
#         @Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) could run on GPU
#           @Expression <AttributeReference> Y#5 could run on GPU
#         @Expression <ScalaUDF> UDF(Y#5) could run on GPU
#           @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/07/22 22:34:40 WARN GpuOverrides:
# ! <DeserializeToObjectExec> cannot run on GPU because not all expressions can be replaced; GPU does not currently support the operator class org.apache.spark.sql.execution.DeserializeToObjectExec
#   ! <CreateExternalRow> createexternalrow(newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize, StructField(raw_text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#     ! <Invoke> newInstance(class org.apache.spark.ml.linalg.VectorUDT).deserialize cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#       ! <NewInstance> newInstance(class org.apache.spark.ml.linalg.VectorUDT) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.NewInstance
#       !Expression <AttributeReference> raw_text_features#6166 cannot run on GPU because expression AttributeReference raw_text_features#6166 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#   !Expression <AttributeReference> obj#6187 cannot run on GPU because expression AttributeReference obj#6187 produces an unsupported type ObjectType(interface org.apache.spark.sql.Row)
#   !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [raw_text_features#6166]
#     !Expression <Alias> UDF(UDF(UDF(text#67))) AS raw_text_features#6166 cannot run on GPU because expression Alias UDF(UDF(UDF(text#67))) AS raw_text_features#6166 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(UDF(UDF(text#67))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#       !Expression <ScalaUDF> UDF(UDF(UDF(text#67))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(text#67))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <ScalaUDF> UDF(UDF(text#67)) could run on GPU
#           @Expression <ScalaUDF> UDF(text#67) could run on GPU
#             @Expression <AttributeReference> text#67 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#         @Expression <AttributeReference> text#67 could run on GPU
#         @Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) could run on GPU
#           @Expression <AttributeReference> Y#5 could run on GPU
# ...
#     !Exec <ProjectExec> cannot run on GPU because not all expressions can be replaced; unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#11159]
#       @Expression <AttributeReference> label#9745 could run on GPU
#       !Expression <Alias> UDF(struct(text_features, UDF(UDF(filtered_words#9790)), bigrams_features, UDF(UDF(UDF(filtered_words#9790))), w2v_features, UDF(filtered_words#9790), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) AS features#11159 cannot run on GPU because expression Alias UDF(struct(text_features, UDF(UDF(filtered_words#9790)), bigrams_features, UDF(UDF(UDF(filtered_words#9790))), w2v_features, UDF(filtered_words#9790), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) AS features#11159 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; input expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#9790)), bigrams_features, UDF(UDF(UDF(filtered_words#9790))), w2v_features, UDF(filtered_words#9790), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#         !Expression <ScalaUDF> UDF(struct(text_features, UDF(UDF(filtered_words#9790)), bigrams_features, UDF(UDF(UDF(filtered_words#9790))), w2v_features, UDF(filtered_words#9790), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) cannot run on GPU because expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#9790)), bigrams_features, UDF(UDF(UDF(filtered_words#9790))), w2v_features, UDF(filtered_words#9790), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; param expression CreateNamedStruct struct(text_features, UDF(UDF(filtered_words#9790)), bigrams_features, UDF(UDF(UDF(filtered_words#9790))), w2v_features, UDF(filtered_words#9790), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123) (child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#           !Expression <CreateNamedStruct> struct(text_features, UDF(UDF(filtered_words#9790)), bigrams_features, UDF(UDF(UDF(filtered_words#9790))), w2v_features, UDF(filtered_words#9790), tags_tags, UDF(UDF(tags_list#77)), title_len_double_VectorAssembler_b2c93055655c, cast(title_len#87 as double), body_len_double_VectorAssembler_b2c93055655c, cast(body_len#98 as double), punct_count_double_VectorAssembler_b2c93055655c, cast(punct_count#110 as double), avg_word_len, avg_word_len#123) cannot run on GPU because value expression ScalaUDF UDF(UDF(UDF(filtered_words#9790))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); unsupported data type in output: StructType(StructField(text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(bigrams_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(w2v_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(tags_tags,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(title_len_double_VectorAssembler_b2c93055655c,DoubleType,true),StructField(body_len_double_VectorAssembler_b2c93055655c,DoubleType,true),StructField(punct_count_double_VectorAssembler_b2c93055655c,DoubleType,false),StructField(avg_word_len,DoubleType,true)); value expression ScalaUDF UDF(UDF(filtered_words#9790)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(filtered_words#9790) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(tags_list#77)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#             @Expression <Literal> text_features could run on GPU
#             !Expression <ScalaUDF> UDF(UDF(filtered_words#9790)) cannot run on GPU because param expression ScalaUDF UDF(filtered_words#9790) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(filtered_words#9790)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#               !Expression <ScalaUDF> UDF(filtered_words#9790) cannot run on GPU because expression ScalaUDF UDF(filtered_words#9790) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 @Expression <AttributeReference> filtered_words#9790 could run on GPU
#             @Expression <Literal> bigrams_features could run on GPU
#             !Expression <ScalaUDF> UDF(UDF(UDF(filtered_words#9790))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(filtered_words#9790))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; param expression ScalaUDF UDF(UDF(filtered_words#9790)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#               !Expression <ScalaUDF> UDF(UDF(filtered_words#9790)) cannot run on GPU because expression ScalaUDF UDF(UDF(filtered_words#9790)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 @Expression <ScalaUDF> UDF(filtered_words#9790) could run on GPU
#                   @Expression <AttributeReference> filtered_words#9790 could run on GPU
#             @Expression <Literal> w2v_features could run on GPU
#             !Expression <ScalaUDF> UDF(filtered_words#9790) cannot run on GPU because expression ScalaUDF UDF(filtered_words#9790) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#               @Expression <AttributeReference> filtered_words#9790 could run on GPU
#             @Expression <Literal> tags_tags could run on GPU
#             !Expression <ScalaUDF> UDF(UDF(tags_list#77)) cannot run on GPU because param expression ScalaUDF UDF(tags_list#77) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(tags_list#77)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#               !Expression <ScalaUDF> UDF(tags_list#77) cannot run on GPU because expression ScalaUDF UDF(tags_list#77) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 @Expression <AttributeReference> tags_list#77 could run on GPU
#             @Expression <Literal> title_len_double_VectorAssembler_b2c93055655c could run on GPU
#             @Expression <Cast> cast(title_len#87 as double) could run on GPU
#               @Expression <AttributeReference> title_len#87 could run on GPU
#             @Expression <Literal> body_len_double_VectorAssembler_b2c93055655c could run on GPU
#             @Expression <Cast> cast(body_len#98 as double) could run on GPU
#               @Expression <AttributeReference> body_len#98 could run on GPU
#             @Expression <Literal> punct_count_double_VectorAssembler_b2c93055655c could run on GPU
#             @Expression <Cast> cast(punct_count#110 as double) could run on GPU
#               @Expression <AttributeReference> punct_count#110 could run on GPU
#             @Expression <Literal> avg_word_len could run on GPU
#             @Expression <AttributeReference> avg_word_len#123 could run on GPU
#             ! <TableCacheQueryStageExec> cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.adaptive.TableCacheQueryStageExec
#
# 25/07/22 22:38:46 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/07/22 22:38:49 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/07/22 22:38:57 WARN DAGScheduler: Broadcasting large task binary with size 4.0 MiB
# 25/07/22 22:39:27 WARN DAGScheduler: Broadcasting large task binary with size 5.2 MiB
# 25/07/22 22:40:04 WARN DAGScheduler: Broadcasting large task binary with size 5.3 MiB
# 25/07/22 22:40:09 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 25/07/22 22:40:14 WARN DAGScheduler: Broadcasting large task binary with size 5.6 MiB
# 25/07/22 22:40:20 WARN DAGScheduler: Broadcasting large task binary with size 5.8 MiB
# ERROR:root:Exception while sending command.                         (0 + 1) / 1]
# Traceback (most recent call last):
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# An error occurred: An error occurred while calling o2738.fit
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3136/173698342.py", line 22, in <module>
#     cv_model = crossval.fit(train_data)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/base.py", line 205, in fit
#     return self._fit(dataset)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/tuning.py", line 847, in _fit
#     for j, metric, subModel in pool.imap_unordered(lambda f: f(), tasks):
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/multiprocessing/pool.py", line 873, in next
#     raise value
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/tuning.py", line 847, in <lambda>
#     for j, metric, subModel in pool.imap_unordered(lambda f: f(), tasks):
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/util.py", line 342, in wrapped
#     return f(*args, **kwargs)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/tuning.py", line 113, in singleTask
#     index, model = next(modelIter)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/base.py", line 98, in __next__
#     return index, self.fitSingleModel(index)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/base.py", line 156, in fitSingleModel
#     return estimator.fit(dataset, paramMaps[index])
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/base.py", line 203, in fit
#     return self.copy(params)._fit(dataset)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/pipeline.py", line 134, in _fit
#     model = stage.fit(dataset)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/base.py", line 205, in fit
#     return self._fit(dataset)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/wrapper.py", line 381, in _fit
#     java_model = self._fit_java(dataset)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/ml/wrapper.py", line 378, in _fit_java
#     return self._java_obj.fit(dataset._jdf)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/java_gateway.py", line 1322, in __call__
#     return_value = get_return_value(
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py", line 179, in deco
#     return f(*a, **kw)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/protocol.py", line 334, in get_return_value
#     raise Py4JError(
# py4j.protocol.Py4JError: An error occurred while calling o2738.fit
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# /home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/context.py:657: RuntimeWarning: Unable to cleanly shutdown Spark JVM process. It is possible that the process has crashed, been killed or may also be in a zombie state.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3136/173698342.py", line 49, in <module>
#     spark.stop()
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/sql/session.py", line 1799, in stop
#     self._jvm.SparkSession.clearDefaultSession()
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/java_gateway.py", line 1712, in __getattr__
#     answer = self._gateway_client.send_command(
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/java_gateway.py", line 1036, in send_command
#     connection = self._get_connection()
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/clientserver.py", line 284, in _get_connection
#     connection = self._create_new_connection()
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/clientserver.py", line 291, in _create_new_connection
#     connection.connect_to_java_server()
#   File "/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/py4j/clientserver.py", line 438, in connect_to_java_server
#     self.socket.connect((self.java_address, self.java_port))
# ConnectionRefusedError: [Errno 111] Connection refused
# Error stopping Spark session: [Errno 111] Connection refused
