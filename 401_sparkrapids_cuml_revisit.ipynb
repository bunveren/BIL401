# %%
import re
import traceback
import time
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col, length, concat_ws, regexp_replace, size, split, array_contains, expr, array_distinct, array_remove
from pyspark.sql.types import StringType, IntegerType, DoubleType, ArrayType
from pyspark.ml import Pipeline
from pyspark.ml.feature import Tokenizer, StopWordsRemover, HashingTF, IDF, StringIndexer, VectorAssembler, NGram, Word2Vec
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from spark_rapids_ml.classification import LogisticRegression, RandomForestClassifier

spark = (SparkSession.builder
    .appName("GPU_Optimized_RAPIDS")
    .master("local[*]")
    .config("spark.driver.memory","24g")
    .config("spark.executor.memory", "24g")
    .config("spark.executor.cores", "4")
    .config("spark.driver.cores", "4")
    .config("spark.sql.shuffle.partitions", "200")
    .config("spark.plugins", "com.nvidia.spark.SQLPlugin")
    .config("spark.driver.host", "localhost")
    .config("spark.rapids.sql.explain", "ALL")
    .config("spark.rapids.sql.allowMultipleJars", "ALWAYS")
    .config("spark.rapids.sql.enabled", "true")
    .config("spark.rapids.memory.hostStorageFraction", "0.8")
    .config("spark.rapids.memory.deviceStorageFraction", "0.8")
    .config("spark.rapids.sql.concurrentGpuTasks", "8")
    .config("spark.memory.offHeap.enabled", "true")
    .config("spark.memory.offHeap.size", "8g")
    .config("spark.rapids.memory.gpu.allocation.limit", "0.9")
    .config("spark.rapids.host.shim.async", "true")
    .config("spark.sql.session.timeZone", "UTC")
    .config("spark.rapids.sql.exec.CollectLimitExec", "true")
    .config("spark.rapids.sql.rowBasedUDF.enabled", "true")
    .config("spark.sql.inMemoryColumnarStorage.batchSerializer", "com.nvidia.spark.rapids.shims.SparkShimServiceProvider")
    .getOrCreate()
)

data_path = "/mnt/c/Users/BerenÜnveren/Desktop/BIL401/data/train.csv"

try:
    print("--- Data Loading ---")
    start_load_time = time.time()
    df = spark.read.format("csv") \
        .option("header", "true") \
        .option("quote", "\"") \
        .option("multiLine", "true") \
        .option("inferSchema", "true") \
        .load(data_path)
    load_time = time.time() - start_load_time
    print(f"Data load time: {load_time:.2f} seconds")
    print("data schema:")
    df.printSchema()
    print("Y column distribution after load (should be HQ, LQ_EDIT, LQ_CLOSE):")
    df.groupBy("Y").count().show()

    print("--- Data Cleaning and Feature Engineering (initial steps) ---")
    start_clean_feature_time = time.time()
    df_clean = df.na.drop(subset=["Title", "Body", "Tags", "Y"]) \
        .withColumn("CleanBody", regexp_replace(col("Body"), "<.*?>", "")) \
        .withColumn("text", concat_ws(" ", col("Title"), col("CleanBody")))

    df_clean = df_clean.withColumn("tags_list", split(expr("TRIM(REPLACE(REPLACE(Tags, '<', ' '), '>', ' '))")," "))

    df_featured = df_clean.withColumn("title_len", length(col("Title"))) \
        .withColumn("body_len", length(col("CleanBody"))) \
        .withColumn("punct_count", length(regexp_replace(col("text"), "[?!]", ""))) \
        .withColumn("avg_word_len", col("text").cast(StringType()).cast(DoubleType()) / (size(split(col("text"), " ")) + 1e-6))
    df_featured = df_clean.withColumn("title_len", length(col("Title"))) \
        .withColumn("body_len", length(col("CleanBody"))) \
        .withColumn("punct_count", length(regexp_replace(col("text"), "[?!]", ""))) \
        .withColumn("avg_word_len", 
                    length(regexp_replace(col("text"), " ", "")).cast(DoubleType()) / \
                    (size(split(col("text"), " ")) + 1e-6))


    clean_feature_time = time.time() - start_clean_feature_time
    print(f"Initial data cleaning and feature engineering time: {clean_feature_time:.2f} seconds")

    label_indexer = StringIndexer(inputCol="Y", outputCol="label", handleInvalid="skip")

    stopwords_remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")
    ngram = NGram(n=2, inputCol="filtered_words", outputCol="bigrams")

    hashing_tf_text = HashingTF(inputCol="filtered_words", outputCol="raw_text_features", numFeatures=20000)
    idf_text = IDF(inputCol="raw_text_features", outputCol="text_features")

    hashing_tf_bigrams = HashingTF(inputCol="bigrams", outputCol="raw_bigrams_features", numFeatures=20000)
    idf_bigrams = IDF(inputCol="raw_bigrams_features", outputCol="bigrams_features")

    w2v = Word2Vec(vectorSize=100, minCount=5, inputCol="filtered_words", outputCol="w2v_features")

    hashing_tf_tags = HashingTF(inputCol="tags_list", outputCol="raw_tags_features", numFeatures=5000)
    idf_tags = IDF(inputCol="raw_tags_features", outputCol="tags_tags")

    feature_assembler = VectorAssembler(
        inputCols=["text_features", "bigrams_features", "w2v_features", "tags_tags",
                   "title_len", "body_len", "punct_count", "avg_word_len"],
        outputCol="features"
    )

    df_processed = df_featured.withColumn("words", split(col("text"), " "))
    (train_data, test_data) = df_processed.randomSplit([0.8, 0.2], seed=42)

    train_data.cache()
    test_data.cache()
    train_data.count()
    test_data.count()
    
    print(f"Train data count: {train_data.count()}, Test data count: {test_data.count()}")

    print("\n--- Logistic Regression Training ---")
    lr = LogisticRegression(featuresCol="features", labelCol="label", maxIter=10)
    lr_pipeline = Pipeline(stages=[
        label_indexer,
        stopwords_remover,
        ngram,
        hashing_tf_text, idf_text, hashing_tf_bigrams, idf_bigrams, w2v, hashing_tf_tags, idf_tags,
        feature_assembler, lr
    ])

    start_lr_train_time = time.time()
    lr_model = lr_pipeline.fit(train_data)
    lr_train_time = time.time() - start_lr_train_time
    print(f"Logistic Regression training time: {lr_train_time:.2f} seconds")

    start_lr_predict_time = time.time()
    lr_predictions = lr_model.transform(test_data)
    lr_predict_time = time.time() - start_lr_predict_time
    print(f"Logistic Regression prediction time: {lr_predict_time:.2f} seconds")

    evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction")
    accuracy_lr = evaluator.setMetricName("accuracy").evaluate(lr_predictions)
    f1_score_lr = evaluator.setMetricName("f1").evaluate(lr_predictions)

    print("\nLogistic Regression Results:")
    print(f"Accuracy: {accuracy_lr:.4f}")
    print(f"F1 Score: {f1_score_lr:.4f}")
    print("Confusion Matrix:")
    lr_predictions.groupBy("label", "prediction").count().orderBy("label", "prediction").show()

except Exception as e:
    print(f"An error occurred: {e}")
    traceback.print_exc()
# Out:
# 25/08/08 17:09:20 WARN Utils: Your hostname, DESKTOP-15VE119 resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/08/08 17:09:20 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/08 17:09:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/08/08 17:09:23 WARN RapidsPluginUtils: RAPIDS Accelerator 24.02.0 using cudf 24.02.1.
# 25/08/08 17:09:23 WARN RapidsPluginUtils: spark.rapids.sql.multiThreadedRead.numThreads is set to 20.
# 25/08/08 17:09:23 WARN RapidsPluginUtils: Multiple cudf jars found in the classpath:
# revison: dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/rapids-4-spark_2.12-24.02.0.jar
# 	version=24.02.1
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T05:34:16Z
# 	url=https://github.com/rapidsai/cudf.git
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/cudf-24.02.2-cuda12.jar
# 	version=24.02.2
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T07:51:45Z
# Please make sure there is only one cudf jar in the classpath.
# 25/08/08 17:09:23 WARN RapidsPluginUtils: RAPIDS Accelerator is enabled, to disable GPU support set `spark.rapids.sql.enabled` to false.
# 25/08/08 17:09:23 WARN RapidsPluginUtils: spark.rapids.sql.explain is set to `ALL`. Set it to 'NONE' to suppress the diagnostics logging about the query placement on the GPU.
# 25/08/08 17:09:32 WARN RapidsPluginUtils: Multiple cudf jars found in the classpath:
# revison: dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/rapids-4-spark_2.12-24.02.0.jar
# 	version=24.02.1
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T05:34:16Z
# 	url=https://github.com/rapidsai/cudf.git
# 	jar URL: jar:file:/home/bunveren/miniconda3/envs/rapids-24.02/lib/python3.10/site-packages/pyspark/jars/cudf-24.02.2-cuda12.jar
# 	version=24.02.2
# 	user=
# 	revision=dd34fdbe35e68ba56a2183f11ed822ddaa6c927b
# 	branch=HEAD
# 	date=2024-02-28T07:51:45Z
# Please make sure there is only one cudf jar in the classpath.
# 25/08/08 17:09:34 ERROR Inbox: Ignoring error
# java.lang.NullPointerException
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:600)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 25/08/08 17:09:34 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: java.lang.NullPointerException
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:600)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# --- Data Loading ---
# Data load time: 6.39 seconds
# data schema:
# root
#  |-- Id: string (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Body: string (nullable = true)
#  |-- Tags: string (nullable = true)
#  |-- CreationDate: string (nullable = true)
#  |-- Y: string (nullable = true)
#
# Y column distribution after load (should be HQ, LQ_EDIT, LQ_CLOSE):
# 25/08/08 17:09:43 WARN GpuOverrides:
# *Exec <CollectLimitExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     *Expression <Alias> cast(count(1)#18L as string) AS count#26 will run on GPU
#       *Expression <Cast> cast(count(1)#18L as string) will run on GPU
#     *Exec <ShuffleExchangeExec> will run on GPU
#       *Partitioning <HashPartitioning> will run on GPU
#       *Exec <HashAggregateExec> will run on GPU
#         *Expression <AggregateExpression> partial_count(1) will run on GPU
#           *Expression <Count> count(1) will run on GPU
#         *Exec <FileSourceScanExec> will run on GPU
#
# 25/08/08 17:09:44 WARN GpuOverrides:
# *Exec <CollectLimitExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     *Expression <Alias> cast(count(1)#18L as string) AS count#26 will run on GPU
#       *Expression <Cast> cast(count(1)#18L as string) will run on GPU
#     *Exec <ShuffleExchangeExec> will run on GPU
#       *Partitioning <HashPartitioning> will run on GPU
#       *Exec <HashAggregateExec> will run on GPU
#         *Expression <AggregateExpression> partial_count(1) will run on GPU
#           *Expression <Count> count(1) will run on GPU
#         *Exec <FileSourceScanExec> will run on GPU
#
# 25/08/08 17:09:44 WARN GpuOverrides:
# *Exec <CollectLimitExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     *Expression <Alias> cast(count(1)#18L as string) AS count#26 will run on GPU
#       *Expression <Cast> cast(count(1)#18L as string) will run on GPU
#     *Exec <ShuffleExchangeExec> will run on GPU
#       *Partitioning <HashPartitioning> will run on GPU
#       *Exec <HashAggregateExec> will run on GPU
#         *Expression <AggregateExpression> partial_count(1) will run on GPU
#           *Expression <Count> count(1) will run on GPU
#         *Exec <FileSourceScanExec> will run on GPU
#
# 25/08/08 17:09:44 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <HashPartitioning> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     *Exec <FileSourceScanExec> will run on GPU
#
# 25/08/08 17:09:45 WARN GpuOverrides:                                (0 + 1) / 1]
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> cast(count(1)#18L as string) AS count#26 will run on GPU
#     *Expression <Cast> cast(count(1)#18L as string) will run on GPU
#
# 25/08/08 17:09:45 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> cast(count(1)#18L as string) AS count#26 will run on GPU
#     *Expression <Cast> cast(count(1)#18L as string) will run on GPU
#   *Exec <AQEShuffleReadExec> will run on GPU
# +--------+-----+
# |       Y|count|
# +--------+-----+
# |LQ_CLOSE|15000|
# |      HQ|15000|
# | LQ_EDIT|15000|
# +--------+-----+
#
# --- Data Cleaning and Feature Engineering (initial steps) ---
# Initial data cleaning and feature engineering time: 0.31 seconds
# 25/08/08 17:09:47 WARN GpuOverrides:
# *Exec <SampleExec> will run on GPU
#   *Exec <SortExec> will run on GPU
#     *Expression <SortOrder> Id#0 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Title#1 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Body#2 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Tags#3 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> CreationDate#4 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Y#5 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> CleanBody#58 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> text#66 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> tags_list#75 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> title_len#135 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> body_len#146 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> punct_count#158 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> avg_word_len#171 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> words#185 ASC NULLS FIRST will run on GPU
#     *Exec <ProjectExec> will run on GPU
#       *Expression <Alias> length(regexp_replace(text#66, [?!], , 1)) AS punct_count#158 will run on GPU
#         *Expression <Length> length(regexp_replace(text#66, [?!], , 1)) will run on GPU
#           *Expression <RegExpReplace> regexp_replace(text#66, [?!], , 1) will run on GPU
#       *Expression <Alias> (cast(length(regexp_replace(text#66,  , , 1)) as double) / (cast(size(split(text#66,  , -1), true) as double) + 1.0E-6)) AS avg_word_len#171 will run on GPU
#         *Expression <Divide> (cast(length(regexp_replace(text#66,  , , 1)) as double) / (cast(size(split(text#66,  , -1), true) as double) + 1.0E-6)) will run on GPU
#           *Expression <Cast> cast(length(regexp_replace(text#66,  , , 1)) as double) will run on GPU
#             *Expression <Length> length(regexp_replace(text#66,  , , 1)) will run on GPU
#               *Expression <RegExpReplace> regexp_replace(text#66,  , , 1) will run on GPU
#           *Expression <Add> (cast(size(split(text#66,  , -1), true) as double) + 1.0E-6) will run on GPU
#             *Expression <Cast> cast(size(split(text#66,  , -1), true) as double) will run on GPU
#               *Expression <Size> size(split(text#66,  , -1), true) will run on GPU
#                 *Expression <StringSplit> split(text#66,  , -1) will run on GPU
#       *Expression <Alias> split(text#66,  , -1) AS words#185 will run on GPU
#         *Expression <StringSplit> split(text#66,  , -1) will run on GPU
#       *Exec <ProjectExec> will run on GPU
#         *Expression <Alias> concat_ws( , Title#1, CleanBody#58) AS text#66 will run on GPU
#           *Expression <ConcatWs> concat_ws( , Title#1, CleanBody#58) will run on GPU
#         *Expression <Alias> split(trim(replace(replace(Tags#3, <,  ), >,  ), None),  , -1) AS tags_list#75 will run on GPU
#           *Expression <StringSplit> split(trim(replace(replace(Tags#3, <,  ), >,  ), None),  , -1) will run on GPU
#             *Expression <StringTrim> trim(replace(replace(Tags#3, <,  ), >,  ), None) will run on GPU
#               *Expression <StringReplace> replace(replace(Tags#3, <,  ), >,  ) will run on GPU
#                 *Expression <StringReplace> replace(Tags#3, <,  ) will run on GPU
#         *Expression <Alias> length(Title#1) AS title_len#135 will run on GPU
#           *Expression <Length> length(Title#1) will run on GPU
#         *Expression <Alias> length(CleanBody#58) AS body_len#146 will run on GPU
#           *Expression <Length> length(CleanBody#58) will run on GPU
#         *Exec <ProjectExec> will run on GPU
#           *Expression <Alias> regexp_replace(Body#2, <.*?>, , 1) AS CleanBody#58 will run on GPU
#             *Expression <RegExpReplace> regexp_replace(Body#2, <.*?>, , 1) will run on GPU
#           *Exec <FilterExec> will run on GPU
#             *Expression <AtLeastNNonNulls> atleastnnonnulls(4, Title#1, Body#2, Tags#3, Y#5) will run on GPU
#             *Exec <FileSourceScanExec> will run on GPU
#
# 25/08/08 17:09:47 WARN GpuOverrides:
# *Exec <SampleExec> will run on GPU
#   *Exec <SortExec> will run on GPU
#     *Expression <SortOrder> Id#0 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Title#1 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Body#2 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Tags#3 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> CreationDate#4 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> Y#5 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> CleanBody#58 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> text#66 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> tags_list#75 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> title_len#135 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> body_len#146 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> punct_count#158 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> avg_word_len#171 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> words#185 ASC NULLS FIRST will run on GPU
#     *Exec <ProjectExec> will run on GPU
#       *Expression <Alias> length(regexp_replace(text#66, [?!], , 1)) AS punct_count#158 will run on GPU
#         *Expression <Length> length(regexp_replace(text#66, [?!], , 1)) will run on GPU
#           *Expression <RegExpReplace> regexp_replace(text#66, [?!], , 1) will run on GPU
#       *Expression <Alias> (cast(length(regexp_replace(text#66,  , , 1)) as double) / (cast(size(split(text#66,  , -1), true) as double) + 1.0E-6)) AS avg_word_len#171 will run on GPU
#         *Expression <Divide> (cast(length(regexp_replace(text#66,  , , 1)) as double) / (cast(size(split(text#66,  , -1), true) as double) + 1.0E-6)) will run on GPU
#           *Expression <Cast> cast(length(regexp_replace(text#66,  , , 1)) as double) will run on GPU
#             *Expression <Length> length(regexp_replace(text#66,  , , 1)) will run on GPU
#               *Expression <RegExpReplace> regexp_replace(text#66,  , , 1) will run on GPU
#           *Expression <Add> (cast(size(split(text#66,  , -1), true) as double) + 1.0E-6) will run on GPU
#             *Expression <Cast> cast(size(split(text#66,  , -1), true) as double) will run on GPU
#               *Expression <Size> size(split(text#66,  , -1), true) will run on GPU
#                 *Expression <StringSplit> split(text#66,  , -1) will run on GPU
#       *Expression <Alias> split(text#66,  , -1) AS words#185 will run on GPU
#         *Expression <StringSplit> split(text#66,  , -1) will run on GPU
#       *Exec <ProjectExec> will run on GPU
#         *Expression <Alias> concat_ws( , Title#1, CleanBody#58) AS text#66 will run on GPU
#           *Expression <ConcatWs> concat_ws( , Title#1, CleanBody#58) will run on GPU
#         *Expression <Alias> split(trim(replace(replace(Tags#3, <,  ), >,  ), None),  , -1) AS tags_list#75 will run on GPU
#           *Expression <StringSplit> split(trim(replace(replace(Tags#3, <,  ), >,  ), None),  , -1) will run on GPU
#             *Expression <StringTrim> trim(replace(replace(Tags#3, <,  ), >,  ), None) will run on GPU
#               *Expression <StringReplace> replace(replace(Tags#3, <,  ), >,  ) will run on GPU
#                 *Expression <StringReplace> replace(Tags#3, <,  ) will run on GPU
#         *Expression <Alias> length(Title#1) AS title_len#135 will run on GPU
#           *Expression <Length> length(Title#1) will run on GPU
#         *Expression <Alias> length(CleanBody#58) AS body_len#146 will run on GPU
#           *Expression <Length> length(CleanBody#58) will run on GPU
#         *Exec <ProjectExec> will run on GPU
#           *Expression <Alias> regexp_replace(Body#2, <.*?>, , 1) AS CleanBody#58 will run on GPU
#             *Expression <RegExpReplace> regexp_replace(Body#2, <.*?>, , 1) will run on GPU
#           *Exec <FilterExec> will run on GPU
#             *Expression <AtLeastNNonNulls> atleastnnonnulls(4, Title#1, Body#2, Tags#3, Y#5) will run on GPU
#             *Exec <FileSourceScanExec> will run on GPU
#
# 25/08/08 17:09:47 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#354L AS count#355L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:47 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#354L AS count#355L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:47 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#354L AS count#355L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:47 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:53 WARN GpuOverrides:                                (0 + 1) / 1]
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#354L AS count#355L will run on GPU
#
# 25/08/08 17:09:53 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#354L AS count#355L will run on GPU
#
# 25/08/08 17:09:53 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#743L AS count#744L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:53 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#743L AS count#744L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:53 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#743L AS count#744L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:53 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:57 WARN GpuOverrides:                                (0 + 1) / 1]
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#743L AS count#744L will run on GPU
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#743L AS count#744L will run on GPU
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1132L AS count#1133L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1132L AS count#1133L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1132L AS count#1133L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1132L AS count#1133L will run on GPU
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1132L AS count#1133L will run on GPU
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1520L AS count#1521L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1520L AS count#1521L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1520L AS count#1521L will run on GPU
#   *Exec <ShuffleExchangeExec> will run on GPU
#     *Partitioning <SinglePartition$> will run on GPU
#     *Exec <HashAggregateExec> will run on GPU
#       *Expression <AggregateExpression> partial_count(1) will run on GPU
#         *Expression <Count> count(1) will run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <ShuffleExchangeExec> will run on GPU
#   *Partitioning <SinglePartition$> will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> partial_count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1520L AS count#1521L will run on GPU
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# *Exec <HashAggregateExec> will run on GPU
#   *Expression <AggregateExpression> count(1) will run on GPU
#     *Expression <Count> count(1) will run on GPU
#   *Expression <Alias> count(1)#1520L AS count#1521L will run on GPU
# Train data count: 35997, Test data count: 9003
#
# --- Logistic Regression Training ---
# 25/08/08 17:09:57 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@19d1772d, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1903 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1903 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1905 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1903 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@19d1772d, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#2119 could run on GPU
#       @Expression <AttributeReference> buf#2120 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@19d1772d, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1903 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1903 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1905 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1903 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@19d1772d, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       @Expression <AttributeReference> buf#2119 could run on GPU
#       @Expression <AttributeReference> buf#2120 could run on GPU
#       !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#         @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/08/08 17:09:57 WARN GpuOverrides:
# !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#   @Expression <AggregateExpression> stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@19d1772d, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#     ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#       ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#         ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#           @Expression <AttributeReference> Y#5 could run on GPU
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#         ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#       ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#         ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#   @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1903 could run on GPU
#   @Expression <Alias> StringIndexerAggregator(org.apache.spark.sql.Row)#1903 AS StringIndexerAggregator(org.apache.spark.sql.Row)#1905 could run on GPU
#     @Expression <AttributeReference> StringIndexerAggregator(org.apache.spark.sql.Row)#1903 could run on GPU
#   !Exec <ShuffleExchangeExec> cannot run on GPU because Columnar exchange without columnar children is inefficient
#     @Partitioning <SinglePartition$> could run on GPU
#     !Exec <ObjectHashAggregateExec> cannot run on GPU because not all expressions can be replaced
#       @Expression <AggregateExpression> partial_stringindexeraggregator(org.apache.spark.ml.feature.StringIndexerAggregator@19d1772d, Some(createexternalrow(Y#5.toString, StructField(Y,StringType,true))), Some(interface org.apache.spark.sql.Row), Some(StructType(StructField(Y,StringType,true))), encodeusingserializer(input[0, java.lang.Object, true], true), decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true), encodeusingserializer(input[0, java.lang.Object, true], true), BinaryType, true, 0, 0) could run on GPU
#         ! <ComplexTypedAggregateExpression> StringIndexerAggregator(org.apache.spark.sql.Row) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.execution.aggregate.ComplexTypedAggregateExpression
#           ! <CreateExternalRow> createexternalrow(Y#5.toString, StructField(Y,StringType,true)) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.CreateExternalRow
#             ! <Invoke> Y#5.toString cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.Invoke
#               @Expression <AttributeReference> Y#5 could run on GPU
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
#             ! <BoundReference> input[0, java.lang.Object, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <DecodeUsingSerializer> decodeusingserializer(input[0, binary, true], Array[org.apache.spark.util.collection.OpenHashMap], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.DecodeUsingSerializer
#             ! <BoundReference> input[0, binary, true] cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.BoundReference
#           ! <EncodeUsingSerializer> encodeusingserializer(input[0, java.lang.Object, true], true) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.objects.EncodeUsingSerializer
# ...
#             @Expression <Literal> vector_type_c3BhcmstcmFwaWRzLW1sCg== could run on GPU
#             @Expression <GetStructField> unwrap_udt(features#4843).type could run on GPU
#               ! <UnwrapUDT> unwrap_udt(features#4843) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.UnwrapUDT
#                 !Expression <AttributeReference> features#4843 cannot run on GPU because expression AttributeReference features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#             @Expression <Literal> vector_size_c3BhcmstcmFwaWRzLW1sCg== could run on GPU
#             @Expression <GetStructField> unwrap_udt(features#4843).size could run on GPU
#               ! <UnwrapUDT> unwrap_udt(features#4843) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.UnwrapUDT
#                 !Expression <AttributeReference> features#4843 cannot run on GPU because expression AttributeReference features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#             @Expression <Literal> vector_indices_c3BhcmstcmFwaWRzLW1sCg== could run on GPU
#             @Expression <GetStructField> unwrap_udt(features#4843).indices could run on GPU
#               ! <UnwrapUDT> unwrap_udt(features#4843) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.UnwrapUDT
#                 !Expression <AttributeReference> features#4843 cannot run on GPU because expression AttributeReference features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#             @Expression <Literal> cuml_values_c3BhcmstcmFwaWRzLW1sCg== could run on GPU
#             @Expression <Cast> cast(unwrap_udt(features#4843).values as array<float>) could run on GPU
#               @Expression <GetStructField> unwrap_udt(features#4843).values could run on GPU
#                 ! <UnwrapUDT> unwrap_udt(features#4843) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.UnwrapUDT
#                   !Expression <AttributeReference> features#4843 cannot run on GPU because expression AttributeReference features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <AttributeReference> pythonUDF0#6227 could run on GPU
#         !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#4843]; not all expressions can be replaced
#           @Expression <AttributeReference> label#4589 could run on GPU
#           !Expression <Alias> UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) AS features#4843 cannot run on GPU because input expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression Alias UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) AS features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#             !Expression <ScalaUDF> UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) cannot run on GPU because param expression CreateNamedStruct struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171) (child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#               !Expression <CreateNamedStruct> struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171) cannot run on GPU because value expression ScalaUDF UDF(filtered_words#4611) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(filtered_words#4611)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(UDF(filtered_words#4611))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(tags_list#75)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); unsupported data type in output: StructType(StructField(text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(bigrams_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(w2v_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(tags_tags,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(title_len_double_VectorAssembler_59b9803732c0,DoubleType,true),StructField(body_len_double_VectorAssembler_59b9803732c0,DoubleType,true),StructField(punct_count_double_VectorAssembler_59b9803732c0,DoubleType,false),StructField(avg_word_len,DoubleType,true))
#                 @Expression <Literal> text_features could run on GPU
#                 !Expression <ScalaUDF> UDF(UDF(filtered_words#4611)) cannot run on GPU because param expression ScalaUDF UDF(filtered_words#4611) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(filtered_words#4611)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                   !Expression <ScalaUDF> UDF(filtered_words#4611) cannot run on GPU because expression ScalaUDF UDF(filtered_words#4611) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                     @Expression <AttributeReference> filtered_words#4611 could run on GPU
#                 @Expression <Literal> bigrams_features could run on GPU
#                 !Expression <ScalaUDF> UDF(UDF(UDF(filtered_words#4611))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(filtered_words#4611))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; param expression ScalaUDF UDF(UDF(filtered_words#4611)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#                   !Expression <ScalaUDF> UDF(UDF(filtered_words#4611)) cannot run on GPU because expression ScalaUDF UDF(UDF(filtered_words#4611)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                     @Expression <ScalaUDF> UDF(filtered_words#4611) could run on GPU
#                       @Expression <AttributeReference> filtered_words#4611 could run on GPU
#                 @Expression <Literal> w2v_features could run on GPU
#                 !Expression <ScalaUDF> UDF(filtered_words#4611) cannot run on GPU because expression ScalaUDF UDF(filtered_words#4611) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                   @Expression <AttributeReference> filtered_words#4611 could run on GPU
#                 @Expression <Literal> tags_tags could run on GPU
#                 !Expression <ScalaUDF> UDF(UDF(tags_list#75)) cannot run on GPU because param expression ScalaUDF UDF(tags_list#75) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(tags_list#75)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                   !Expression <ScalaUDF> UDF(tags_list#75) cannot run on GPU because expression ScalaUDF UDF(tags_list#75) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                     @Expression <AttributeReference> tags_list#75 could run on GPU
#                 @Expression <Literal> title_len_double_VectorAssembler_59b9803732c0 could run on GPU
#                 @Expression <Cast> cast(title_len#135 as double) could run on GPU
#                   @Expression <AttributeReference> title_len#135 could run on GPU
#                 @Expression <Literal> body_len_double_VectorAssembler_59b9803732c0 could run on GPU
#                 @Expression <Cast> cast(body_len#146 as double) could run on GPU
#                   @Expression <AttributeReference> body_len#146 could run on GPU
#                 @Expression <Literal> punct_count_double_VectorAssembler_59b9803732c0 could run on GPU
#                 @Expression <Cast> cast(punct_count#158 as double) could run on GPU
#                   @Expression <AttributeReference> punct_count#158 could run on GPU
#                 @Expression <Literal> avg_word_len could run on GPU
#                 @Expression <AttributeReference> avg_word_len#171 could run on GPU
#           *Exec <ProjectExec> will run on GPU
#             *Expression <Alias> UDF(words#185) AS filtered_words#4611 will run on GPU
#               *Expression <ScalaUDF> UDF(words#185) will run on GPU
#             *Exec <ProjectExec> will run on GPU
#               *Expression <Alias> UDF(Y#5) AS label#4589 will run on GPU
#                 *Expression <ScalaUDF> UDF(Y#5) will run on GPU
#               *Exec <FilterExec> will run on GPU
#                 *Expression <And> (atleastnnonnulls(1, Y#5) AND UDF(Y#5)) will run on GPU
#                   *Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) will run on GPU
#                   *Expression <ScalaUDF> UDF(Y#5) will run on GPU
#                 !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#                   @Expression <AttributeReference> Y#5 could run on GPU
#                   @Expression <AttributeReference> avg_word_len#171 could run on GPU
#                   @Expression <AttributeReference> body_len#146 could run on GPU
#                   @Expression <AttributeReference> punct_count#158 could run on GPU
#                   @Expression <AttributeReference> tags_list#75 could run on GPU
#                   @Expression <AttributeReference> title_len#135 could run on GPU
#                   @Expression <AttributeReference> words#185 could run on GPU
#                   @Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) could run on GPU
#                     @Expression <AttributeReference> Y#5 could run on GPU
#                   @Expression <ScalaUDF> UDF(Y#5) could run on GPU
#                     @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/08/08 17:13:04 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/08/08 17:13:07 WARN GpuOverrides:                                (0 + 1) / 1]
# *Exec <ProjectExec> will run on GPU
#   *Expression <Alias> cast(label#4589 as string) AS label#6081 will run on GPU
#     *Expression <Cast> cast(label#4589 as string) will run on GPU
#   *Expression <Alias> cast(prediction#5300 as string) AS prediction#6082 will run on GPU
#     *Expression <Cast> cast(prediction#5300 as string) will run on GPU
#   *Expression <Alias> cast(count#6074L as string) AS count#6083 will run on GPU
#     *Expression <Cast> cast(count#6074L as string) will run on GPU
#   *Exec <SortExec> will run on GPU
#     *Expression <SortOrder> label#4589 ASC NULLS FIRST will run on GPU
#     *Expression <SortOrder> prediction#5300 ASC NULLS FIRST will run on GPU
#     *Exec <ShuffleExchangeExec> will run on GPU
#       *Partitioning <RangePartitioning> will run on GPU
#         *Expression <SortOrder> label#4589 ASC NULLS FIRST will run on GPU
#         *Expression <SortOrder> prediction#5300 ASC NULLS FIRST will run on GPU
#       *Exec <HashAggregateExec> will run on GPU
#         *Expression <AggregateExpression> count(1) will run on GPU
#           *Expression <Count> count(1) will run on GPU
#         *Expression <Alias> count(1)#6073L AS count#6074L will run on GPU
#
# 25/08/08 17:13:07 WARN GpuOverrides:
# *Exec <TakeOrderedAndProjectExec> will run on GPU
#   *Expression <SortOrder> label#4589 ASC NULLS FIRST will run on GPU
#   *Expression <SortOrder> prediction#5300 ASC NULLS FIRST will run on GPU
#   *Expression <Alias> cast(label#4589 as string) AS label#6081 will run on GPU
#     *Expression <Cast> cast(label#4589 as string) will run on GPU
#   *Expression <Alias> cast(prediction#5300 as string) AS prediction#6082 will run on GPU
#     *Expression <Cast> cast(prediction#5300 as string) will run on GPU
#   *Expression <Alias> cast(count#6074L as string) AS count#6083 will run on GPU
#     *Expression <Cast> cast(count#6074L as string) will run on GPU
#   *Exec <HashAggregateExec> will run on GPU
#     *Expression <AggregateExpression> count(1) will run on GPU
#       *Expression <Count> count(1) will run on GPU
#     *Expression <Alias> count(1)#6073L AS count#6074L will run on GPU
#     *Exec <AQEShuffleReadExec> will run on GPU
#
# 25/08/08 17:13:07 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  0.0|       0.0| 1920|
# |  0.0|       1.0|  615|
# |  0.0|       2.0|  442|
# |  1.0|       0.0|  705|
# |  1.0|       1.0| 2030|
# |  1.0|       2.0|  245|
# |  2.0|       0.0|  400|
# |  2.0|       1.0|  193|
# |  2.0|       2.0| 2453|
# +-----+----------+-----+

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np 

try:
    times_gpu = {
        "Data Load": load_time,
        "Initial Cleaning & FE": clean_feature_time,
        "LR Training": lr_train_time,
        "LR Prediction": lr_predict_time
    }

    labels_gpu = list(times_gpu.keys())
    values_gpu = list(times_gpu.values())

    plt.figure(figsize=(12, 7))
    plt.bar(labels_gpu, values_gpu, color=['skyblue', 'lightgreen', 'salmon', 'orchid'])
    plt.ylabel("Time (seconds)")
    plt.title("Time Breakdown of GPU-Enabled Pipeline Stages")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.savefig("gpu_pipeline_time_breakdown_srai.png")
    plt.show()

except NameError:
    print("Time tracking variables not defined, skipping GPU time breakdown plot.")
except Exception as e:
    print(f"Error generating GPU time breakdown plot: {e}")
    traceback.print_exc()

try:
    predictions_pd = lr_predictions.select("label", "prediction").toPandas()
    cm = confusion_matrix(predictions_pd["label"], predictions_pd["prediction"])
    class_labels = ["HQ", "LQ_EDIT", "LQ_CLOSE"]

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=class_labels, yticklabels=class_labels)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix for Logistic Regression (GPU Version)")
    plt.savefig("gpu_confusion_matrix_lr_srai.png")
    plt.show()

except Exception as e:
    print(f"Error generating GPU confusion matrix plot: {e}")
    traceback.print_exc()


finally:
    try:
        if 'spark' in locals() and spark is not None:
            spark.stop()
    except Exception as e:
        print(f"Error stopping Spark session: {e}")
        traceback.print_exc()
# Out:
# 25/08/08 17:13:11 WARN GpuOverrides:
# !Exec <ProjectExec> cannot run on GPU because unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#4843]
#   @Expression <AttributeReference> label#4589 could run on GPU
#   @Expression <Alias> pythonUDF0#6604.prediction AS prediction#5300 could run on GPU
#     @Expression <GetStructField> pythonUDF0#6604.prediction could run on GPU
#       @Expression <AttributeReference> pythonUDF0#6604 could run on GPU
#   !Exec <ArrowEvalPythonExec> cannot run even partially on the GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#4843]; not all expressions can be replaced; unsupported data types in input: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#4843]
#     @Expression <PythonUDF> predict_udf(struct(vector_type_c3BhcmstcmFwaWRzLW1sCg==, unwrap_udt(features#4843).type, vector_size_c3BhcmstcmFwaWRzLW1sCg==, unwrap_udt(features#4843).size, vector_indices_c3BhcmstcmFwaWRzLW1sCg==, unwrap_udt(features#4843).indices, cuml_values_c3BhcmstcmFwaWRzLW1sCg==, cast(unwrap_udt(features#4843).values as array<float>)))#5268 could not block GPU acceleration
#       @Expression <CreateNamedStruct> struct(vector_type_c3BhcmstcmFwaWRzLW1sCg==, unwrap_udt(features#4843).type, vector_size_c3BhcmstcmFwaWRzLW1sCg==, unwrap_udt(features#4843).size, vector_indices_c3BhcmstcmFwaWRzLW1sCg==, unwrap_udt(features#4843).indices, cuml_values_c3BhcmstcmFwaWRzLW1sCg==, cast(unwrap_udt(features#4843).values as array<float>)) could run on GPU
#         @Expression <Literal> vector_type_c3BhcmstcmFwaWRzLW1sCg== could run on GPU
#         @Expression <GetStructField> unwrap_udt(features#4843).type could run on GPU
#           ! <UnwrapUDT> unwrap_udt(features#4843) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.UnwrapUDT
#             !Expression <AttributeReference> features#4843 cannot run on GPU because expression AttributeReference features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <Literal> vector_size_c3BhcmstcmFwaWRzLW1sCg== could run on GPU
#         @Expression <GetStructField> unwrap_udt(features#4843).size could run on GPU
#           ! <UnwrapUDT> unwrap_udt(features#4843) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.UnwrapUDT
#             !Expression <AttributeReference> features#4843 cannot run on GPU because expression AttributeReference features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <Literal> vector_indices_c3BhcmstcmFwaWRzLW1sCg== could run on GPU
#         @Expression <GetStructField> unwrap_udt(features#4843).indices could run on GPU
#           ! <UnwrapUDT> unwrap_udt(features#4843) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.UnwrapUDT
#             !Expression <AttributeReference> features#4843 cannot run on GPU because expression AttributeReference features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         @Expression <Literal> cuml_values_c3BhcmstcmFwaWRzLW1sCg== could run on GPU
#         @Expression <Cast> cast(unwrap_udt(features#4843).values as array<float>) could run on GPU
#           @Expression <GetStructField> unwrap_udt(features#4843).values could run on GPU
#             ! <UnwrapUDT> unwrap_udt(features#4843) cannot run on GPU because GPU does not currently support the operator class org.apache.spark.sql.catalyst.expressions.UnwrapUDT
#               !Expression <AttributeReference> features#4843 cannot run on GPU because expression AttributeReference features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#     @Expression <AttributeReference> pythonUDF0#6604 could run on GPU
#     !Exec <ProjectExec> cannot run on GPU because unsupported data types in output: org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 [features#4843]; not all expressions can be replaced
#       @Expression <AttributeReference> label#4589 could run on GPU
#       !Expression <Alias> UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) AS features#4843 cannot run on GPU because input expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression Alias UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) AS features#4843 produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#         !Expression <ScalaUDF> UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) cannot run on GPU because param expression CreateNamedStruct struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171) (child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported, child org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#           !Expression <CreateNamedStruct> struct(text_features, UDF(UDF(filtered_words#4611)), bigrams_features, UDF(UDF(UDF(filtered_words#4611))), w2v_features, UDF(filtered_words#4611), tags_tags, UDF(UDF(tags_list#75)), title_len_double_VectorAssembler_59b9803732c0, cast(title_len#135 as double), body_len_double_VectorAssembler_59b9803732c0, cast(body_len#146 as double), punct_count_double_VectorAssembler_59b9803732c0, cast(punct_count#158 as double), avg_word_len, avg_word_len#171) cannot run on GPU because value expression ScalaUDF UDF(filtered_words#4611) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(filtered_words#4611)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(UDF(filtered_words#4611))) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); value expression ScalaUDF UDF(UDF(tags_list#75)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); unsupported data type in output: StructType(StructField(text_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(bigrams_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(w2v_features,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(tags_tags,org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7,true),StructField(title_len_double_VectorAssembler_59b9803732c0,DoubleType,true),StructField(body_len_double_VectorAssembler_59b9803732c0,DoubleType,true),StructField(punct_count_double_VectorAssembler_59b9803732c0,DoubleType,false),StructField(avg_word_len,DoubleType,true))
#             @Expression <Literal> text_features could run on GPU
#             !Expression <ScalaUDF> UDF(UDF(filtered_words#4611)) cannot run on GPU because param expression ScalaUDF UDF(filtered_words#4611) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(filtered_words#4611)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#               !Expression <ScalaUDF> UDF(filtered_words#4611) cannot run on GPU because expression ScalaUDF UDF(filtered_words#4611) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 @Expression <AttributeReference> filtered_words#4611 could run on GPU
#             @Expression <Literal> bigrams_features could run on GPU
#             !Expression <ScalaUDF> UDF(UDF(UDF(filtered_words#4611))) cannot run on GPU because expression ScalaUDF UDF(UDF(UDF(filtered_words#4611))) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7; param expression ScalaUDF UDF(UDF(filtered_words#4611)) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported)
#               !Expression <ScalaUDF> UDF(UDF(filtered_words#4611)) cannot run on GPU because expression ScalaUDF UDF(UDF(filtered_words#4611)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 @Expression <ScalaUDF> UDF(filtered_words#4611) could run on GPU
#                   @Expression <AttributeReference> filtered_words#4611 could run on GPU
#             @Expression <Literal> w2v_features could run on GPU
#             !Expression <ScalaUDF> UDF(filtered_words#4611) cannot run on GPU because expression ScalaUDF UDF(filtered_words#4611) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#               @Expression <AttributeReference> filtered_words#4611 could run on GPU
#             @Expression <Literal> tags_tags could run on GPU
#             !Expression <ScalaUDF> UDF(UDF(tags_list#75)) cannot run on GPU because param expression ScalaUDF UDF(tags_list#75) (org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7 is not supported); expression ScalaUDF UDF(UDF(tags_list#75)) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#               !Expression <ScalaUDF> UDF(tags_list#75) cannot run on GPU because expression ScalaUDF UDF(tags_list#75) produces an unsupported type org.apache.spark.ml.linalg.VectorUDT@3bfc3ba7
#                 @Expression <AttributeReference> tags_list#75 could run on GPU
#             @Expression <Literal> title_len_double_VectorAssembler_59b9803732c0 could run on GPU
#             @Expression <Cast> cast(title_len#135 as double) could run on GPU
#               @Expression <AttributeReference> title_len#135 could run on GPU
#             @Expression <Literal> body_len_double_VectorAssembler_59b9803732c0 could run on GPU
#             @Expression <Cast> cast(body_len#146 as double) could run on GPU
#               @Expression <AttributeReference> body_len#146 could run on GPU
#             @Expression <Literal> punct_count_double_VectorAssembler_59b9803732c0 could run on GPU
#             @Expression <Cast> cast(punct_count#158 as double) could run on GPU
#               @Expression <AttributeReference> punct_count#158 could run on GPU
#             @Expression <Literal> avg_word_len could run on GPU
#             @Expression <AttributeReference> avg_word_len#171 could run on GPU
#       *Exec <ProjectExec> will run on GPU
#         *Expression <Alias> UDF(words#185) AS filtered_words#4611 will run on GPU
#           *Expression <ScalaUDF> UDF(words#185) will run on GPU
#         *Exec <ProjectExec> will run on GPU
#           *Expression <Alias> UDF(Y#5) AS label#4589 will run on GPU
#             *Expression <ScalaUDF> UDF(Y#5) will run on GPU
#           *Exec <FilterExec> will run on GPU
#             *Expression <And> (atleastnnonnulls(1, Y#5) AND UDF(Y#5)) will run on GPU
#               *Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) will run on GPU
#               *Expression <ScalaUDF> UDF(Y#5) will run on GPU
#             !Exec <InMemoryTableScanExec> cannot run on GPU because ParquetCachedBatchSerializer is not being used
#               @Expression <AttributeReference> Y#5 could run on GPU
#               @Expression <AttributeReference> avg_word_len#171 could run on GPU
#               @Expression <AttributeReference> body_len#146 could run on GPU
#               @Expression <AttributeReference> punct_count#158 could run on GPU
#               @Expression <AttributeReference> tags_list#75 could run on GPU
#               @Expression <AttributeReference> title_len#135 could run on GPU
#               @Expression <AttributeReference> words#185 could run on GPU
#               @Expression <AtLeastNNonNulls> atleastnnonnulls(1, Y#5) could run on GPU
#                 @Expression <AttributeReference> Y#5 could run on GPU
#               @Expression <ScalaUDF> UDF(Y#5) could run on GPU
#                 @Expression <AttributeReference> Y#5 could run on GPU
#
# 25/08/08 17:13:11 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
